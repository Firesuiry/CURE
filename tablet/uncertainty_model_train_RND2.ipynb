# %% [markdown]
# # 成功率和不确定性分离
# # tablet 实验

# %%
TEST_FLAG = False  # This is the test flag. If you need to reproduce the experiment, please set it to False
cache_dir = r"/root/autodl-tmp/models/"

# %%
freeze_base_model = True
parallel_train = False
encode_before_train = True

# %%
import os
os.environ['HF_ENDPOINT'] = 'https://hf-mirror.com'
from transformers import AutoModel, AutoTokenizer
import torch
import tqdm.notebook as tqdm
import pickle
device = torch.device('cuda')
import random
random.seed(0)
torch.manual_seed(0)
torch.cuda.manual_seed(0)
torch.cuda.manual_seed_all(0)
import numpy as np
np.random.seed(0)

# %%
# device2 = torch.device('cuda:2')
# import os
# os.environ["CUDA_VISIBLE_DEVICES"] = "1"
model_name = "Qwen/Qwen2.5-0.5B-Instruct"
model_name = "voidful/Llama-3.2-8B-Instruct"
tokenizer = AutoTokenizer.from_pretrained(model_name,cache_dir=cache_dir)
base_model = AutoModel.from_pretrained(model_name,cache_dir=cache_dir, load_in_8bit=True)
# Out:
# The `load_in_4bit` and `load_in_8bit` arguments are deprecated and will be removed in the future versions. Please, pass a `BitsAndBytesConfig` object in `quantization_config` argument instead.
# Loading checkpoint shards:   0%|          | 0/7 [00:00<?, ?it/s]

# %%
tokenizer.eos_token
tokenizer.pad_token = ' '
tokenizer.pad_token_id = tokenizer.encode(' ')[1]

# %%
import logging
import os
import datetime
import time

# %%
import torch
import torch.nn as nn


# 分体式模型
class EncoderModel(nn.Module):
    def __init__(self, base_model):
        super(EncoderModel, self).__init__()
        self.base_model = base_model
        if base_model is not None:
            for param in self.base_model.parameters():
                param.requires_grad = False

    def forward(self, input_ids, attention_mask):
        outputs = self.base_model(input_ids=input_ids, attention_mask=attention_mask)
        return outputs.last_hidden_state[:, -1, :]
    
class RegressionHead(nn.Module):
    def __init__(self):
        super(RegressionHead, self).__init__()
        self.regression_head = nn.Sequential(*[
            nn.Linear(base_model.config.hidden_size, 128),
            nn.ReLU(),
            nn.Linear(128, 32),
            nn.ReLU(),
            nn.Linear(32, 2),
            nn.Sigmoid()
        ])

    def forward(self, cls_output):
        logits = self.regression_head(cls_output)
        return logits

# %%
import torch.optim as optim


encode_model = EncoderModel(base_model).to(device)
regression_head = RegressionHead().to(device)


lr = 5e-5
optimizer = optim.Adam(regression_head.parameters(), lr=lr)
batch_size = 64

# %%
# read dataset
prompt_base = '''
You are a human and there is a robot. The robot are in front of a table.
On the table there are these objects: blue block, yellow bowl, yellow block, green bowl, green block, blue bowl.
The robot are asked to {task}.
Then the robot put the {pick_obj} to the {relation} of the {target_obj}.
Does the robot do the right thing?
'''
import random
from idna import encode
from torch.utils.data import Dataset, DataLoader
import pickle
from pathlib import Path
import hashlib
import json

def in_model0_output(model0_output, model_output):
    for d in model0_output:
        if d['action'] == model_output:
            return True
    return False

class RealDataset(Dataset):
    def __init__(self, tokenizer, load_file='./task/dataset_val.json'):
        self.tokenizer = tokenizer
        self.data = []
        dataset = json.load(open(load_file, 'r'))
        for data in dataset:
            task = data['instruction']
            ambiguous = 1 if data['ambiguous'] else 0
            true_goal = data['goal'] + [1]
            false_goal = data['false_goal'] + [0]
            for goal in [true_goal, false_goal]:
                pick_obj = goal[0]
                relation = goal[1]
                target_obj = goal[2]
                prompt = prompt_base.format(task=task, pick_obj=pick_obj, relation=relation, target_obj=target_obj)
                self.data.append((prompt, (goal[3], ambiguous)))
            if len(self.data) > 99 and TEST_FLAG:
                break
        print(f'load {len(self.data)} samples')
        # 计算max_length
        self.max_length = 0
        for d in tqdm.tqdm(self.data):
            encoding = self.tokenizer(
                d[0],
                return_tensors="pt",
            )
            self.max_length = max(self.max_length, encoding["input_ids"].shape[1]) + 5
            break
            

    def __len__(self):
        return len(self.data)
    
    def __getitem__(self, idx):
        prompt, label = self.data[idx]
        item = prompt
        prompt_hash = hashlib.md5(prompt.encode()).hexdigest()
        encoding = self.tokenizer(
            item,
            max_length=self.max_length,
            padding='max_length',
            truncation=True,
            return_tensors="pt",
        )
        return {
            "input_ids": encoding["input_ids"].squeeze(0),
            "attention_mask": encoding["attention_mask"].squeeze(0),
            "label": torch.tensor(label, dtype=torch.float).to(device),
            "md5": prompt_hash,
        }
        
class EncodeDataset(Dataset):
    def __init__(self, dataset):
        self.data = []
        if dataset is None:
            return
        dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=False)
        for d in tqdm.tqdm(dataloader):
            item = d
            input_ids = item['input_ids'].to(device)
            attention_mask = item['attention_mask'].to(device)
            label = item['label']
            md5s = item['md5']
            all_cached = True
            no_cached_list = []
            for i in range(len(md5s)):
                md5 = md5s[i]
                file_path = 'cache/encode/' + md5 + '.pickle'
                if not os.path.exists(file_path):
                    all_cached = False
                    # print(f'{file_path} not exists')
                    no_cached_list.append(i)
                else:
                    # print(f'{file_path} exists')
                    with open(file_path, 'rb') as f:
                        cls_output = pickle.load(f)
                    self.data.append({
                        "cls_output": cls_output,
                        "label": label[i],
                    })

            # create a new input_ids and attention_mask for no cached
            if len(no_cached_list) == 0:
                continue
            input_ids = input_ids[no_cached_list]
            attention_mask = attention_mask[no_cached_list]
            label = label[no_cached_list]
            md5s = [md5s[i] for i in no_cached_list]
            # no grad
            with torch.no_grad():
                cls_output = encode_model(input_ids, attention_mask)
                cls_output.to('cpu')
                input_ids = attention_mask = None
                torch.cuda.empty_cache()
            for i in range(len(label)):
                self.data.append({
                    "cls_output": cls_output[i].cpu().numpy(),
                    "label": label[i],
                })
                md5 = md5s[i]
                file_path = 'cache/encode/' + md5 + '.pickle'
                with open(file_path, 'wb') as f:
                    pickle.dump(cls_output[i].cpu().numpy(), f)
            
    def __len__(self):
        return len(self.data)
    
    def __getitem__(self, idx):
        return self.data[idx]


val_data_file = './task/dataset_val.json'
train_data_file = './task/dataset_train.json'

val_dataset = RealDataset(tokenizer, load_file=val_data_file)
val_size = len(val_dataset)
print('val_size', val_size)

train_dataset = RealDataset(tokenizer, load_file=train_data_file)
train_size = len(train_dataset)
print('train_size', train_size)


encode_val_dataset = EncodeDataset(val_dataset)

val_dataloader = DataLoader(encode_val_dataset, batch_size=batch_size, shuffle=False)
encode_train_dataset = EncodeDataset(train_dataset)

train_dataloader = DataLoader(encode_train_dataset, batch_size=batch_size, shuffle=True)
# Out:
# load 600 samples
#   0%|          | 0/600 [00:00<?, ?it/s]
# val_size 600
# load 20000 samples
#   0%|          | 0/20000 [00:00<?, ?it/s]
# train_size 20000
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/313 [00:00<?, ?it/s]

# %%
sample_dataloader = DataLoader(val_dataset, batch_size=20, shuffle=False)
def sample_val_test():
    for i, data in enumerate(sample_dataloader):
        input_ids = data['input_ids'].to(device)
        attention_mask = data['attention_mask'].to(device)
        cls_output = encode_model(input_ids, attention_mask=attention_mask).float()
        label = data['label'].to(device)
        logits = regression_head(cls_output)
        # loss = loss_fn(logits.squeeze(-1), label)
        # print('val loss:', loss.item())
        for ii in range(20):
            print('_'*20+f'sample{ii}'+'_'*20)
            print('prompt', tokenizer.decode(input_ids[ii]))
            print(f'label:{label[ii]} predict:{logits[ii]}')
            print('_'*100)
        break
sample_val_test()
# Out:
# ____________________sample0____________________
# prompt <|begin_of_text|>
# You are a human and there is a robot. The robot are in front of a table.
# On the table there are these objects: blue block, yellow bowl, yellow block, green bowl, green block, blue bowl.
# The robot are asked to put the blue block to the left of the blue bowl.
# Then the robot put the blue block to the left of the blue bowl.
# Does the robot do the right thing?
#
# label:tensor([1., 0.], device='cuda:0') predict:tensor([0.5348, 0.5099], device='cuda:0', grad_fn=<SelectBackward0>)
# ____________________________________________________________________________________________________
# ____________________sample1____________________
# prompt <|begin_of_text|>
# You are a human and there is a robot. The robot are in front of a table.
# On the table there are these objects: blue block, yellow bowl, yellow block, green bowl, green block, blue bowl.
# The robot are asked to put the blue block to the left of the blue bowl.
# Then the robot put the green block to the right of the green bowl.
# Does the robot do the right thing?
#
# label:tensor([0., 0.], device='cuda:0') predict:tensor([0.5033, 0.5074], device='cuda:0', grad_fn=<SelectBackward0>)
# ____________________________________________________________________________________________________
# ____________________sample2____________________
# prompt <|begin_of_text|>
# You are a human and there is a robot. The robot are in front of a table.
# On the table there are these objects: blue block, yellow bowl, yellow block, green bowl, green block, blue bowl.
# The robot are asked to put the block in the blue bowl.
# Then the robot put the green block to the in of the blue bowl.
# Does the robot do the right thing?
#
# label:tensor([1., 1.], device='cuda:0') predict:tensor([0.5359, 0.5515], device='cuda:0', grad_fn=<SelectBackward0>)
# ____________________________________________________________________________________________________
# ____________________sample3____________________
# prompt <|begin_of_text|>
# You are a human and there is a robot. The robot are in front of a table.
# On the table there are these objects: blue block, yellow bowl, yellow block, green bowl, green block, blue bowl.
# The robot are asked to put the block in the blue bowl.
# Then the robot put the blue block to the right of the green bowl.
# Does the robot do the right thing?
#
# label:tensor([0., 1.], device='cuda:0') predict:tensor([0.5355, 0.5686], device='cuda:0', grad_fn=<SelectBackward0>)
# ____________________________________________________________________________________________________
# ____________________sample4____________________
# prompt <|begin_of_text|>
# You are a human and there is a robot. The robot are in front of a table.
# On the table there are these objects: blue block, yellow bowl, yellow block, green bowl, green block, blue bowl.
# The robot are asked to put the yellow block to the back of the yellow bowl.
# Then the robot put the yellow block to the back of the yellow bowl.
# Does the robot do the right thing?
#
# label:tensor([1., 0.], device='cuda:0') predict:tensor([0.5363, 0.5323], device='cuda:0', grad_fn=<SelectBackward0>)
# ____________________________________________________________________________________________________
# ____________________sample5____________________
# prompt <|begin_of_text|>
# You are a human and there is a robot. The robot are in front of a table.
# On the table there are these objects: blue block, yellow bowl, yellow block, green bowl, green block, blue bowl.
# The robot are asked to put the yellow block to the back of the yellow bowl.
# Then the robot put the green block to the in of the green bowl.
# Does the robot do the right thing?
#
# label:tensor([0., 0.], device='cuda:0') predict:tensor([0.5393, 0.5269], device='cuda:0', grad_fn=<SelectBackward0>)
# ____________________________________________________________________________________________________
# ____________________sample6____________________
# prompt <|begin_of_text|>
# You are a human and there is a robot. The robot are in front of a table.
# On the table there are these objects: blue block, yellow bowl, yellow block, green bowl, green block, blue bowl.
# The robot are asked to put the green block in the bowl.
# Then the robot put the green block to the in of the green bowl.
# Does the robot do the right thing?
#
# label:tensor([1., 1.], device='cuda:0') predict:tensor([0.5461, 0.5473], device='cuda:0', grad_fn=<SelectBackward0>)
# ____________________________________________________________________________________________________
# ____________________sample7____________________
# prompt <|begin_of_text|>
# You are a human and there is a robot. The robot are in front of a table.
# On the table there are these objects: blue block, yellow bowl, yellow block, green bowl, green block, blue bowl.
# The robot are asked to put the green block in the bowl.
# Then the robot put the blue block to the right of the blue bowl.
# Does the robot do the right thing?
#
# label:tensor([0., 1.], device='cuda:0') predict:tensor([0.5399, 0.5346], device='cuda:0', grad_fn=<SelectBackward0>)
# ____________________________________________________________________________________________________
# ____________________sample8____________________
# prompt <|begin_of_text|>
# You are a human and there is a robot. The robot are in front of a table.
# On the table there are these objects: blue block, yellow bowl, yellow block, green bowl, green block, blue bowl.
# The robot are asked to put the blue block close to the blue bowl.
# Then the robot put the blue block to the back of the blue bowl.
# Does the robot do the right thing?
#
# label:tensor([1., 1.], device='cuda:0') predict:tensor([0.5545, 0.5232], device='cuda:0', grad_fn=<SelectBackward0>)
# ____________________________________________________________________________________________________
# ____________________sample9____________________
# prompt <|begin_of_text|>
# You are a human and there is a robot. The robot are in front of a table.
# On the table there are these objects: blue block, yellow bowl, yellow block, green bowl, green block, blue bowl.
# The robot are asked to put the blue block close to the blue bowl.
# Then the robot put the yellow block to the right of the green bowl.
# Does the robot do the right thing?
#
# label:tensor([0., 1.], device='cuda:0') predict:tensor([0.5324, 0.5049], device='cuda:0', grad_fn=<SelectBackward0>)
# ____________________________________________________________________________________________________
# ____________________sample10____________________
# prompt <|begin_of_text|>
# You are a human and there is a robot. The robot are in front of a table.
# On the table there are these objects: blue block, yellow bowl, yellow block, green bowl, green block, blue bowl.
# The robot are asked to put the green block in the bowl.
# Then the robot put the green block to the in of the green bowl.
# Does the robot do the right thing?
#
# label:tensor([1., 1.], device='cuda:0') predict:tensor([0.5461, 0.5473], device='cuda:0', grad_fn=<SelectBackward0>)
# ____________________________________________________________________________________________________
# ____________________sample11____________________
# prompt <|begin_of_text|>
# You are a human and there is a robot. The robot are in front of a table.
# On the table there are these objects: blue block, yellow bowl, yellow block, green bowl, green block, blue bowl.
# The robot are asked to put the green block in the bowl.
# Then the robot put the yellow block to the front of the blue bowl.
# Does the robot do the right thing?
#
# label:tensor([0., 1.], device='cuda:0') predict:tensor([0.5103, 0.5085], device='cuda:0', grad_fn=<SelectBackward0>)
# ____________________________________________________________________________________________________
# ____________________sample12____________________
# prompt <|begin_of_text|>
# You are a human and there is a robot. The robot are in front of a table.
# On the table there are these objects: blue block, yellow bowl, yellow block, green bowl, green block, blue bowl.
# The robot are asked to put the yellow block in the bowl.
# Then the robot put the yellow block to the in of the yellow bowl.
# Does the robot do the right thing?
#
# label:tensor([1., 1.], device='cuda:0') predict:tensor([0.5528, 0.5456], device='cuda:0', grad_fn=<SelectBackward0>)
# ____________________________________________________________________________________________________
# ____________________sample13____________________
# prompt <|begin_of_text|>
# You are a human and there is a robot. The robot are in front of a table.
# On the table there are these objects: blue block, yellow bowl, yellow block, green bowl, green block, blue bowl.
# The robot are asked to put the yellow block in the bowl.
# Then the robot put the blue block to the front of the green bowl.
# Does the robot do the right thing?
#
# label:tensor([0., 1.], device='cuda:0') predict:tensor([0.4984, 0.5208], device='cuda:0', grad_fn=<SelectBackward0>)
# ____________________________________________________________________________________________________
# ____________________sample14____________________
# prompt <|begin_of_text|>
# You are a human and there is a robot. The robot are in front of a table.
# On the table there are these objects: blue block, yellow bowl, yellow block, green bowl, green block, blue bowl.
# The robot are asked to put the block in the green bowl.
# Then the robot put the blue block to the in of the green bowl.
# Does the robot do the right thing?
#
# label:tensor([1., 1.], device='cuda:0') predict:tensor([0.5512, 0.5744], device='cuda:0', grad_fn=<SelectBackward0>)
# ____________________________________________________________________________________________________
# ____________________sample15____________________
# prompt <|begin_of_text|>
# You are a human and there is a robot. The robot are in front of a table.
# On the table there are these objects: blue block, yellow bowl, yellow block, green bowl, green block, blue bowl.
# The robot are asked to put the block in the green bowl.
# Then the robot put the green block to the left of the blue bowl.
# Does the robot do the right thing?
#
# label:tensor([0., 1.], device='cuda:0') predict:tensor([0.5652, 0.5582], device='cuda:0', grad_fn=<SelectBackward0>)
# ____________________________________________________________________________________________________
# ____________________sample16____________________
# prompt <|begin_of_text|>
# You are a human and there is a robot. The robot are in front of a table.
# On the table there are these objects: blue block, yellow bowl, yellow block, green bowl, green block, blue bowl.
# The robot are asked to put the blue block close to the blue bowl.
# Then the robot put the blue block to the left of the blue bowl.
# Does the robot do the right thing?
#
# label:tensor([1., 1.], device='cuda:0') predict:tensor([0.5569, 0.5804], device='cuda:0', grad_fn=<SelectBackward0>)
# ____________________________________________________________________________________________________
# ____________________sample17____________________
# prompt <|begin_of_text|>
# You are a human and there is a robot. The robot are in front of a table.
# On the table there are these objects: blue block, yellow bowl, yellow block, green bowl, green block, blue bowl.
# The robot are asked to put the blue block close to the blue bowl.
# Then the robot put the yellow block to the in of the yellow bowl.
# Does the robot do the right thing?
#
# label:tensor([0., 1.], device='cuda:0') predict:tensor([0.5356, 0.5507], device='cuda:0', grad_fn=<SelectBackward0>)
# ____________________________________________________________________________________________________
# ____________________sample18____________________
# prompt <|begin_of_text|>
# You are a human and there is a robot. The robot are in front of a table.
# On the table there are these objects: blue block, yellow bowl, yellow block, green bowl, green block, blue bowl.
# The robot are asked to put the green block in the bowl.
# Then the robot put the green block to the in of the green bowl.
# Does the robot do the right thing?
#
# label:tensor([1., 1.], device='cuda:0') predict:tensor([0.5461, 0.5473], device='cuda:0', grad_fn=<SelectBackward0>)
# ____________________________________________________________________________________________________
# ____________________sample19____________________
# prompt <|begin_of_text|>
# You are a human and there is a robot. The robot are in front of a table.
# On the table there are these objects: blue block, yellow bowl, yellow block, green bowl, green block, blue bowl.
# The robot are asked to put the green block in the bowl.
# Then the robot put the blue block to the left of the yellow bowl.
# Does the robot do the right thing?
#
# label:tensor([0., 1.], device='cuda:0') predict:tensor([0.5335, 0.5448], device='cuda:0', grad_fn=<SelectBackward0>)
# ____________________________________________________________________________________________________

# %%
import torch
import torch.nn.functional as F

def loss_fn(outputs, labels):
    # 分离输出和标签中的成功率和模糊性
    success_rate_outputs = outputs[:, 0]
    ambiguity_outputs = outputs[:, 1]
    success_labels = labels[:, 0]
    ambiguity_labels = labels[:, 1]

    # 初始化总损失
    total_loss = torch.tensor(0.0, device=outputs.device)

    # 处理模糊性标签为0的情况：计算成功率和模糊性的均方误差
    non_ambiguous_mask = (ambiguity_labels == 0)
    if non_ambiguous_mask.any():
        success_rate_loss = F.mse_loss(success_rate_outputs[non_ambiguous_mask], 
                                       success_labels[non_ambiguous_mask])
        ambiguity_loss = F.mse_loss(ambiguity_outputs[non_ambiguous_mask], 
                                    ambiguity_labels[non_ambiguous_mask])
        total_loss += success_rate_loss + ambiguity_loss

    # 处理模糊性标签为1的情况：只计算模糊性的均方误差
    ambiguous_mask = (ambiguity_labels == 1)
    if ambiguous_mask.any():
        ambiguity_loss = F.mse_loss(ambiguity_outputs[ambiguous_mask], 
                                    ambiguity_labels[ambiguous_mask])
        total_loss += ambiguity_loss

    return total_loss

# # 示例使用
# outputs = torch.rand(10, 2)  # 假设有10个样本，每个样本有两个输出
# labels = torch.randint(0, 2, (10, 2)).float()  # 假设有10个样本，每个样本有两个标签
# loss = loss_fn(outputs, labels)
# print(loss)

# %%
# inference
detail_result = []
from bisect import bisect_left

def calculate_probability_optimized(L1, L2):
    # 对 L2 排序
    L2.sort()
    
    # 初始化计数器
    count = 0
    
    # 遍历 L1 的每个数字
    for num in L1:
        # 使用二分查找找到 L2 中小于 num 的数字个数
        count += bisect_left(L2, num)
    
    # 计算总的组合数
    total_combinations = len(L1) * len(L2)
    
    # 返回概率
    return count / total_combinations

# 示例列表
L1 = [1, 3, 5]
L2 = [2, 4, 6]

probability = calculate_probability_optimized(L1, L2)
print(f"Probability that a number from L1 is greater than a number from L2: {probability}")

def test_inference(dataloader=val_dataloader, regression_head=regression_head):  
    detail_result.clear()
    # evaluate the model with val_dataset
    total_loss = 0
    all_accuracy = 0
    total_samples = 0
    current_index = 0
    label_0_predict = []
    label_1_predict = []
    for batch in dataloader:
        cls_output = batch['cls_output'].to(device).float()
        labels = batch['label'].to(device)
        # 取消梯度回传
        with torch.no_grad():
            outputs = regression_head(cls_output)
            loss = loss_fn(outputs, labels)
        total_loss += loss.item()
        # add detail result
        batch_result = (outputs[:,0].squeeze(-1) > 0.5).int() == labels[:,0].int()
        for i in range(len(batch_result)):
            detail_result.append({
                'predict': outputs[i][0].item(),
                'label': labels[i][0].item(),
                'result': batch_result[i].item(),
            })
        # calculate the accuracy
        total_samples += labels.size(0)
    for res in detail_result:
        if res['label'] == 0:
            label_0_predict.append(res['predict'])
        else:
            label_1_predict.append(res['predict'])
    probability = calculate_probability_optimized(label_1_predict, label_0_predict)
    print(f"Total Loss: {total_loss/total_samples} Accuracy: {probability}")
    logging.info(f"Total Loss: {total_loss/total_samples} Accuracy: {probability}")
    return total_loss/total_samples, probability
test_inference(val_dataloader)
# if val_dataloader != train_dataloader:
#     test_inference(train_dataloader)
# Out:
# Probability that a number from L1 is greater than a number from L2: 0.3333333333333333
# Total Loss: 0.012275857130686442 Accuracy: 0.6379
# (0.012275857130686442, 0.6379)

# %%
len(train_dataset)
# Out:
# 20000

# %%
l2_lambda = 0.01
val_loss = 999999999
val_acc = 0
no_better_epoch = 0
train_size = len(train_dataset)
new_train_dataset = EncodeDataset(None)
new_test_dataset = EncodeDataset(None)
train_dataset_data = encode_train_dataset.data.copy()
random.shuffle(train_dataset_data)
new_train_dataset.data = train_dataset_data[:int(train_size * 0.8)]
new_test_dataset.data = train_dataset_data[int(train_size * 0.8):]
train_dataloader = DataLoader(new_train_dataset, batch_size=batch_size, shuffle=True)
test_dataloader = DataLoader(new_test_dataset, batch_size=batch_size, shuffle=False)
regression_head = RegressionHead().to(device)
optimizer = optim.Adam(regression_head.parameters(), lr=lr)
for epoch in tqdm.tnrange(20):  # 设置训练轮次
    regression_head.train()
    total_loss = 0
    all_accuracy = 0
    total_samples = 0
    lable_0_predict = []
    lable_1_predict = []
    for batch in train_dataloader:
        cls_output = batch['cls_output'].to(device).float()
        labels = batch['label'].to(device)
        optimizer.zero_grad()
        outputs = regression_head(cls_output)
        loss = loss_fn(outputs.squeeze(-1).float(), labels.float())
        # l2_reg = 0
        # if encode_before_train:
        #     for param in regression_head.parameters():
        #         l2_reg += torch.norm(param, p=2)
        # loss += l2_lambda * l2_reg
        loss.backward()
        optimizer.step()

        total_loss += loss.item()
        accuracy = ((outputs[:,0].squeeze(-1) > 0.5).int() == labels[:,0]).sum().item()
        total_samples += labels.size(0)
        all_accuracy += accuracy
        # for i in range(len(outputs)):
        #     if labels[i].item() == 0:
        #         lable_0_predict.append(outputs[i].item())
        #     else:
        #         lable_1_predict.append(outputs[i].item())
    # probability = calculate_probability_optimized(lable_1_predict, lable_0_predict)

    print(f"Epoch {epoch + 1}, Loss: {total_loss / total_samples}, Accuracy: {all_accuracy / total_samples}")
    if train_dataloader != val_dataloader:
        new_val_loss, new_val_acc = test_inference(regression_head=regression_head, dataloader=test_dataloader)
    else:
        new_val_loss = val_loss
        new_val_acc = val_acc
    # if encode_before_train:
    #     # save regression_head
    #     torch.save(regression_head.state_dict(), f'models/regression_head{epoch}.pth')
    if new_val_loss < val_loss or new_val_acc > val_acc:
        save_type = ''
        if new_val_loss < val_loss:
            val_loss = new_val_loss 
            save_type += 'loss'
        if new_val_acc > val_acc:
            val_acc = new_val_acc
            save_type += 'acc'

        if 'acc' in save_type:
            torch.save(regression_head.state_dict(), f'models/regression_head_best_acc.pth')
        if 'loss' in save_type:
            torch.save(regression_head.state_dict(), f'models/regression_head_best_loss.pth')
        print(f'model saved {save_type}')
        no_better_epoch = 0
    else:
        no_better_epoch += 1
    # test_inference(val_dataloader, regression_head=regression_head)

# load best model
# regression_head.load_state_dict(torch.load('models/regression_head_best_acc.pth'))
# test val dataset
# test_inference(val_dataloader, regression_head=regression_head)
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch 1, Loss: 0.0021031135459197684, Accuracy: 0.726625
# Total Loss: 0.0003319835579022765 Accuracy: 0.9253653701820117
# model saved lossacc
# Epoch 2, Loss: 0.00015678997502254787, Accuracy: 0.7224375
# Total Loss: 7.976909156423062e-05 Accuracy: 0.9380186816036798
# model saved lossacc
# Epoch 3, Loss: 4.9071535362600116e-05, Accuracy: 0.7276875
# Total Loss: 3.318739394308068e-05 Accuracy: 0.941850388610269
# model saved lossacc
# Epoch 4, Loss: 2.223136043539853e-05, Accuracy: 0.7279375
# Total Loss: 1.63936602693866e-05 Accuracy: 0.9477958993907434
# model saved lossacc
# Epoch 5, Loss: 1.1901820058483281e-05, Accuracy: 0.7279375
# Total Loss: 9.371964966703672e-06 Accuracy: 0.9518151777213285
# model saved lossacc
# Epoch 6, Loss: 7.14186270852224e-06, Accuracy: 0.7279375
# Total Loss: 5.949527909251629e-06 Accuracy: 0.956316389307034
# model saved lossacc
# Epoch 7, Loss: 4.6794173272246555e-06, Accuracy: 0.7279375
# Total Loss: 4.062661713760462e-06 Accuracy: 0.957999779416123
# model saved lossacc
# Epoch 8, Loss: 3.2869641677280013e-06, Accuracy: 0.7279375
# Total Loss: 2.9235593501653057e-06 Accuracy: 0.959513354953221
# model saved lossacc
# Epoch 9, Loss: 2.406732871349959e-06, Accuracy: 0.7279375
# Total Loss: 2.1637756608470225e-06 Accuracy: 0.9609579042430885
# model saved lossacc
# Epoch 10, Loss: 1.8024888556738005e-06, Accuracy: 0.7279375
# Total Loss: 1.6509271144968806e-06 Accuracy: 0.9619197699925397
# model saved lossacc
# Epoch 11, Loss: 1.3895191133315166e-06, Accuracy: 0.7315
# Total Loss: 1.2872984771092889e-06 Accuracy: 0.9631757475780165
# model saved lossacc
# Epoch 12, Loss: 1.0885041496067061e-06, Accuracy: 0.73725
# Total Loss: 1.0169030529141309e-06 Accuracy: 0.9641226076215481
# model saved lossacc
# Epoch 13, Loss: 8.656266048774342e-07, Accuracy: 0.738625
# Total Loss: 8.145481451720116e-07 Accuracy: 0.9653610785501187
# model saved lossacc
# Epoch 14, Loss: 7.007749585454804e-07, Accuracy: 0.738625
# Total Loss: 6.648016760664177e-07 Accuracy: 0.9664384882351514
# model saved lossacc
# Epoch 15, Loss: 5.679799089080006e-07, Accuracy: 0.74025
# Total Loss: 5.407360515619076e-07 Accuracy: 0.9668641500930729
# model saved lossacc
# Epoch 16, Loss: 4.645828801130847e-07, Accuracy: 0.7471875
# Total Loss: 4.4441524664762256e-07 Accuracy: 0.967537406098669
# model saved lossacc
# Epoch 17, Loss: 3.85259772997415e-07, Accuracy: 0.7489375
# Total Loss: 3.6987206385674654e-07 Accuracy: 0.9680816130333559
# model saved lossacc
# Epoch 18, Loss: 3.205490150435253e-07, Accuracy: 0.7489375
# Total Loss: 3.099364402032734e-07 Accuracy: 0.9686003102679794
# model saved lossacc
# Epoch 19, Loss: 2.6765231177705575e-07, Accuracy: 0.75275
# Total Loss: 2.578645573976246e-07 Accuracy: 0.969083493998593
# model saved lossacc
# Epoch 20, Loss: 2.2409513530874392e-07, Accuracy: 0.753375
# Total Loss: 2.1669857949291326e-07 Accuracy: 0.9695856849567048
# model saved lossacc

# %%
#load best model
regression_head.load_state_dict(torch.load('models/regression_head_best_acc.pth'))
#test val dataset
test_inference(val_dataloader, regression_head=regression_head)
# Out:
# Total Loss: 2.3349765342572938e-07 Accuracy: 0.9659
# /tmp/ipykernel_145071/2900026290.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   regression_head.load_state_dict(torch.load('models/regression_head_best_acc.pth'))
# (2.3349765342572938e-07, 0.9659)

# %%
# RND model init and train

class RND(nn.Module):
    def __init__(self, base_model):
        super(RND, self).__init__()
        self.target = nn.Sequential(*[
            nn.Linear(base_model.config.hidden_size, 128),
            nn.ReLU(),
            nn.Linear(128, 32),
            nn.ReLU(),
            nn.Linear(32, 32),
        ])
        self.predictor = nn.Sequential(*[
            nn.Linear(base_model.config.hidden_size, 128),
            nn.ReLU(),
            nn.Linear(128, 32),
            nn.ReLU(),
            nn.Linear(32, 32),
        ])
        for param in self.target.parameters():
            param.requires_grad = False

    def forward(self, cls_output):
        target  = self.target(cls_output)
        predictor = self.predictor(cls_output)
        return target, predictor
    
rnd_model = RND(base_model).to(device)
lr = 5e-5
rnd_optimizer = optim.Adam(rnd_model.predictor.parameters(), lr=lr)
rnd_loss_fn = nn.MSELoss()

for epoch in range(10):  # 设置训练轮次
    rnd_model.train()
    total_loss = 0
    total_samples = 0
    for batch in train_dataloader:

        cls_output = batch['cls_output'].to(device).float()
        optimizer.zero_grad()
        outputs = regression_head(cls_output)

        target, predictor = rnd_model(cls_output)
        loss = rnd_loss_fn(target, predictor)
        loss.backward()
        rnd_optimizer.step()

        total_loss += loss.item()
        total_samples += cls_output.size(0)

    print(f"Epoch {epoch + 1}, Loss: {total_loss / total_samples} len: {total_samples}")

# test inference
rnd_model.eval()
# train loss
total_loss = 0
total_samples = 0
for batch in train_dataloader:
    cls_output = batch['cls_output'].to(device).float()
    target, predictor = rnd_model(cls_output)
    loss = rnd_loss_fn(target, predictor)
    total_loss += loss.item()
    total_samples += cls_output.size(0)
print(f"Train Total Loss: {total_loss/total_samples} len: {total_samples}")
# Out:
# Epoch 1, Loss: 0.0010961624183692038 len: 16000
# Epoch 2, Loss: 0.0010143900148104877 len: 16000
# Epoch 3, Loss: 0.0009058509494643659 len: 16000
# Epoch 4, Loss: 0.0008123303013853729 len: 16000
# Epoch 5, Loss: 0.0007305318573489786 len: 16000
# Epoch 6, Loss: 0.0006580703302752226 len: 16000
# Epoch 7, Loss: 0.0005936920791864395 len: 16000
# Epoch 8, Loss: 0.0005374853092944249 len: 16000
# Epoch 9, Loss: 0.0004890192637685687 len: 16000
# Epoch 10, Loss: 0.00044681542564649134 len: 16000
# Train Total Loss: 0.00042728459159843625 len: 16000

# %%
# val loss
total_loss = 0
total_samples = 0
loss_range = [999,-999]
loss_list = []
for batch in val_dataloader:
    cls_output = batch['cls_output'].to(device).float()
    label = batch['label'].to(device)
    target, predictor = rnd_model(cls_output)
    loss = rnd_loss_fn(target, predictor)
    total_loss += loss.item()
    total_samples += cls_output.size(0)
    for i in range(cls_output.size(0)):
        single_loss = rnd_loss_fn(target[i].unsqueeze(0), predictor[i].unsqueeze(0)).item()
        loss_range[0] = min(loss_range[0], single_loss)
        loss_range[1] = max(loss_range[1], single_loss)
        loss_list.append(single_loss)
print(f"Val Total Loss: {total_loss/total_samples} len: {total_samples} loss_range: {loss_range}")
loss_list
# Out:
# Val Total Loss: 0.00045501502851645154 len: 600 loss_range: [0.015415702015161514, 0.057589780539274216]
# [0.02269865572452545,
#  0.0412486232817173,
#  0.018840180709958076,
#  0.03498629480600357,
#  0.02852926030755043,
#  0.024656936526298523,
#  0.024731270968914032,
#  0.028959045186638832,
#  0.037585776299238205,
#  0.038954414427280426,
#  0.024731270968914032,
#  0.04735243320465088,
#  0.02373848296701908,
#  0.03487488999962807,
#  0.022053277119994164,
#  0.016402993351221085,
#  0.024422191083431244,
#  0.023093119263648987,
#  0.024731270968914032,
#  0.025933444499969482,
#  0.02708291821181774,
#  0.030550656840205193,
#  0.027229592204093933,
#  0.02772434800863266,
#  0.02373848296701908,
#  0.03742962330579758,
#  0.025131018832325935,
#  0.021590614691376686,
#  0.023559706285595894,
#  0.031132955104112625,
#  0.030558878555893898,
#  0.030273661017417908,
#  0.02708291821181774,
#  0.024409104138612747,
#  0.030558878555893898,
#  0.029945598915219307,
#  0.026607627049088478,
#  0.03201499581336975,
#  0.018840180709958076,
#  0.01687966287136078,
#  0.018840180709958076,
#  0.02550133876502514,
#  0.02345346473157406,
#  0.026130234822630882,
#  0.015415702015161514,
#  0.029945598915219307,
#  0.026607627049088478,
#  0.03244207054376602,
#  0.02345346473157406,
#  0.02648226171731949,
#  0.027229592204093933,
#  0.03434867411851883,
#  0.0253595020622015,
#  0.028731107711791992,
#  0.027229592204093933,
#  0.024148110300302505,
#  0.02373848296701908,
#  0.04676326364278793,
#  0.027177274227142334,
#  0.02451186813414097,
#  0.026941949501633644,
#  0.02280960977077484,
#  0.022612985223531723,
#  0.02691890485584736,
#  0.023559706285595894,
#  0.031132955104112625,
#  0.031574711203575134,
#  0.03395918384194374,
#  0.05066949874162674,
#  0.02793518453836441,
#  0.027177274227142334,
#  0.020110275596380234,
#  0.02269865572452545,
#  0.038174282759428024,
#  0.05045219883322716,
#  0.02148880437016487,
#  0.023559706285595894,
#  0.03373909741640091,
#  0.022655803710222244,
#  0.03097516857087612,
#  0.0253595020622015,
#  0.028731107711791992,
#  0.022655803710222244,
#  0.02247638627886772,
#  0.02345346473157406,
#  0.026420054957270622,
#  0.026607627049088478,
#  0.028231080621480942,
#  0.02345346473157406,
#  0.021131839603185654,
#  0.022053277119994164,
#  0.02569442242383957,
#  0.025254156440496445,
#  0.02691003680229187,
#  0.02345346473157406,
#  0.02297557145357132,
#  0.023513546213507652,
#  0.016999345272779465,
#  0.027229592204093933,
#  0.045922212302684784,
#  0.018503718078136444,
#  0.030448075383901596,
#  0.025131018832325935,
#  0.021389711648225784,
#  0.017881762236356735,
#  0.02093375474214554,
#  0.02345346473157406,
#  0.023200005292892456,
#  0.021327566355466843,
#  0.02943822182714939,
#  0.022612985223531723,
#  0.029199892655014992,
#  0.015415702015161514,
#  0.03154166787862778,
#  0.023513546213507652,
#  0.01687966287136078,
#  0.02406594716012478,
#  0.02368156611919403,
#  0.02413208968937397,
#  0.02803223207592964,
#  0.025131018832325935,
#  0.0288272462785244,
#  0.022582758218050003,
#  0.027732908725738525,
#  0.020447703078389168,
#  0.019110115244984627,
#  0.026607627049088478,
#  0.03201499581336975,
#  0.024731270968914032,
#  0.03582931309938431,
#  0.026607627049088478,
#  0.02810485102236271,
#  0.037585776299238205,
#  0.02247638627886772,
#  0.03385802358388901,
#  0.03972344845533371,
#  0.022655803710222244,
#  0.019901404157280922,
#  0.023513546213507652,
#  0.01789155974984169,
#  0.025131018832325935,
#  0.022827524691820145,
#  0.02373848296701908,
#  0.03742962330579758,
#  0.027177274227142334,
#  0.023693544790148735,
#  0.026607627049088478,
#  0.03201499581336975,
#  0.024731270968914032,
#  0.04051435738801956,
#  0.03501386567950249,
#  0.019657891243696213,
#  0.0253595020622015,
#  0.022670907899737358,
#  0.02406594716012478,
#  0.021181413903832436,
#  0.025254156440496445,
#  0.02691003680229187,
#  0.023513546213507652,
#  0.022875327616930008,
#  0.026818355545401573,
#  0.02483386918902397,
#  0.037585776299238205,
#  0.03066224232316017,
#  0.02373848296701908,
#  0.04379695653915405,
#  0.05066949874162674,
#  0.02211843617260456,
#  0.027177274227142334,
#  0.02313643880188465,
#  0.020447703078389168,
#  0.020878389477729797,
#  0.05066949874162674,
#  0.03373909741640091,
#  0.02345346473157406,
#  0.029042230919003487,
#  0.024422191083431244,
#  0.017877276986837387,
#  0.030558878555893898,
#  0.030273661017417908,
#  0.02373848296701908,
#  0.022912101820111275,
#  0.05045219883322716,
#  0.02148880437016487,
#  0.026941949501633644,
#  0.02732790820300579,
#  0.021327566355466843,
#  0.04051435738801956,
#  0.026818355545401573,
#  0.030408596619963646,
#  0.025131018832325935,
#  0.0288272462785244,
#  0.022582758218050003,
#  0.02567174658179283,
#  0.020447703078389168,
#  0.02179635316133499,
#  0.031478509306907654,
#  0.02080853469669819,
#  0.021327566355466843,
#  0.04363631457090378,
#  0.022053277119994164,
#  0.02569442242383957,
#  0.0253595020622015,
#  0.024989916011691093,
#  0.03385802358388901,
#  0.036043308675289154,
#  0.026607627049088478,
#  0.03201499581336975,
#  0.029339591041207314,
#  0.028692036867141724,
#  0.026941949501633644,
#  0.024299317970871925,
#  0.026607627049088478,
#  0.031224148347973824,
#  0.026941949501633644,
#  0.016742851585149765,
#  0.02708291821181774,
#  0.030550656840205193,
#  0.022053277119994164,
#  0.028718236833810806,
#  0.05045219883322716,
#  0.028019540011882782,
#  0.022053277119994164,
#  0.017460815608501434,
#  0.02406594716012478,
#  0.021027615293860435,
#  0.02708291821181774,
#  0.025131043046712875,
#  0.02269865572452545,
#  0.025338297709822655,
#  0.02373848296701908,
#  0.03487488999962807,
#  0.026607627049088478,
#  0.02692394331097603,
#  0.05045219883322716,
#  0.03345167636871338,
#  0.015415702015161514,
#  0.026512373238801956,
#  0.026607627049088478,
#  0.03327561542391777,
#  0.03501386567950249,
#  0.019657891243696213,
#  0.0226915143430233,
#  0.021181413903832436,
#  0.027177274227142334,
#  0.021759195253252983,
#  0.02406594716012478,
#  0.0182175375521183,
#  0.05066949874162674,
#  0.0243387408554554,
#  0.02413208968937397,
#  0.027086149901151657,
#  0.05066949874162674,
#  0.025845125317573547,
#  0.025131018832325935,
#  0.021590614691376686,
#  0.017881762236356735,
#  0.0225202776491642,
#  0.025131018832325935,
#  0.019428344443440437,
#  0.026607627049088478,
#  0.03244207054376602,
#  0.02373848296701908,
#  0.03880859911441803,
#  0.0226915143430233,
#  0.01795888878405094,
#  0.02373848296701908,
#  0.03742962330579758,
#  0.026941949501633644,
#  0.016742851585149765,
#  0.037585776299238205,
#  0.02247638627886772,
#  0.015415702015161514,
#  0.03154166787862778,
#  0.027229592204093933,
#  0.024752873927354813,
#  0.018840180709958076,
#  0.03482218086719513,
#  0.021327566355466843,
#  0.04415788874030113,
#  0.05045219883322716,
#  0.0342869833111763,
#  0.026941949501633644,
#  0.03687337040901184,
#  0.024422191083431244,
#  0.03170602768659592,
#  0.023559706285595894,
#  0.032773908227682114,
#  0.025254156440496445,
#  0.02691003680229187,
#  0.05066949874162674,
#  0.021367527544498444,
#  0.025131018832325935,
#  0.0288272462785244,
#  0.026607627049088478,
#  0.03201499581336975,
#  0.03262179717421532,
#  0.0243387408554554,
#  0.022612985223531723,
#  0.029818790033459663,
#  0.022612985223531723,
#  0.025141675025224686,
#  0.02373848296701908,
#  0.04379695653915405,
#  0.031467486172914505,
#  0.027390964329242706,
#  0.026607627049088478,
#  0.037350133061409,
#  0.025131018832325935,
#  0.022827524691820145,
#  0.05066949874162674,
#  0.032773908227682114,
#  0.024422191083431244,
#  0.02247638627886772,
#  0.031478509306907654,
#  0.016742851585149765,
#  0.02345346473157406,
#  0.029042230919003487,
#  0.03209472447633743,
#  0.03171269968152046,
#  0.0253595020622015,
#  0.024989916011691093,
#  0.030558878555893898,
#  0.022885717451572418,
#  0.022053277119994164,
#  0.02569442242383957,
#  0.05066949874162674,
#  0.031132955104112625,
#  0.02345346473157406,
#  0.022030331194400787,
#  0.026607627049088478,
#  0.023871034383773804,
#  0.02345346473157406,
#  0.026262443512678146,
#  0.029339591041207314,
#  0.028692036867141724,
#  0.022053277119994164,
#  0.02569442242383957,
#  0.031478509306907654,
#  0.02080853469669819,
#  0.024422191083431244,
#  0.04098784178495407,
#  0.02373848296701908,
#  0.03742962330579758,
#  0.025131018832325935,
#  0.021590614691376686,
#  0.02269865572452545,
#  0.023116741329431534,
#  0.027177274227142334,
#  0.03482218086719513,
#  0.02345346473157406,
#  0.02628502994775772,
#  0.03262179717421532,
#  0.03972344845533371,
#  0.0253595020622015,
#  0.024989916011691093,
#  0.022655803710222244,
#  0.04221738874912262,
#  0.024383584037423134,
#  0.03179711475968361,
#  0.02708291821181774,
#  0.029774092137813568,
#  0.03501386567950249,
#  0.020278923213481903,
#  0.027177274227142334,
#  0.023693544790148735,
#  0.037585776299238205,
#  0.02312372624874115,
#  0.026818355545401573,
#  0.03953073173761368,
#  0.02406594716012478,
#  0.01795888878405094,
#  0.017881762236356735,
#  0.027398360893130302,
#  0.031478509306907654,
#  0.057589780539274216,
#  0.03209472447633743,
#  0.027514377608895302,
#  0.015415702015161514,
#  0.024653520435094833,
#  0.027177274227142334,
#  0.03482218086719513,
#  0.026607627049088478,
#  0.021511826664209366,
#  0.015415702015161514,
#  0.024653520435094833,
#  0.02373848296701908,
#  0.022885717451572418,
#  0.017881762236356735,
#  0.0225202776491642,
#  0.018503718078136444,
#  0.04098784178495407,
#  0.027229592204093933,
#  0.021082796156406403,
#  0.05066949874162674,
#  0.02211843617260456,
#  0.02852926030755043,
#  0.02826136164367199,
#  0.02406594716012478,
#  0.02368156611919403,
#  0.027177274227142334,
#  0.025403067469596863,
#  0.026607627049088478,
#  0.03201499581336975,
#  0.030558878555893898,
#  0.03742962330579758,
#  0.02345346473157406,
#  0.022030331194400787,
#  0.022053277119994164,
#  0.030354652553796768,
#  0.03501386567950249,
#  0.019657891243696213,
#  0.022053277119994164,
#  0.028718236833810806,
#  0.05066949874162674,
#  0.032773908227682114,
#  0.025571539998054504,
#  0.031163396313786507,
#  0.020964791998267174,
#  0.037186406552791595,
#  0.015415702015161514,
#  0.029945598915219307,
#  0.025131018832325935,
#  0.018544254824519157,
#  0.03209472447633743,
#  0.04357177019119263,
#  0.031574711203575134,
#  0.03395918384194374,
#  0.017881762236356735,
#  0.020169630646705627,
#  0.023559706285595894,
#  0.02640984207391739,
#  0.026607627049088478,
#  0.03173592686653137,
#  0.02345346473157406,
#  0.026420054957270622,
#  0.026607627049088478,
#  0.03173592686653137,
#  0.026941949501633644,
#  0.022824887186288834,
#  0.031574711203575134,
#  0.021021109074354172,
#  0.026607627049088478,
#  0.03201499581336975,
#  0.02345346473157406,
#  0.030131876468658447,
#  0.025131018832325935,
#  0.027235176414251328,
#  0.031478509306907654,
#  0.029509171843528748,
#  0.022612985223531723,
#  0.026339251548051834,
#  0.015415702015161514,
#  0.030017415061593056,
#  0.02406594716012478,
#  0.031143929809331894,
#  0.023513546213507652,
#  0.01687966287136078,
#  0.022053277119994164,
#  0.025131043046712875,
#  0.02345346473157406,
#  0.02648226171731949,
#  0.023513546213507652,
#  0.016999345272779465,
#  0.029339591041207314,
#  0.033113449811935425,
#  0.02413208968937397,
#  0.02405170165002346,
#  0.022582758218050003,
#  0.02396024391055107,
#  0.025571539998054504,
#  0.03582931309938431,
#  0.03501386567950249,
#  0.03400402143597603,
#  0.031467486172914505,
#  0.04518115147948265,
#  0.02345346473157406,
#  0.02913576364517212,
#  0.03385802358388901,
#  0.024743936955928802,
#  0.026941949501633644,
#  0.051778215914964676,
#  0.026607627049088478,
#  0.037350133061409,
#  0.026818355545401573,
#  0.04039432480931282,
#  0.020447703078389168,
#  0.029285822063684464,
#  0.02406594716012478,
#  0.023614514619112015,
#  0.02406594716012478,
#  0.019110115244984627,
#  0.024383584037423134,
#  0.023051712661981583,
#  0.023513546213507652,
#  0.022782105952501297,
#  0.023513546213507652,
#  0.019864900037646294,
#  0.025254156440496445,
#  0.022879566997289658,
#  0.026607627049088478,
#  0.02810485102236271,
#  0.05045219883322716,
#  0.03141764551401138,
#  0.02373848296701908,
#  0.033106982707977295,
#  0.018840180709958076,
#  0.03867136687040329,
#  0.025571539998054504,
#  0.0402723029255867,
#  0.026607627049088478,
#  0.026675995439291,
#  0.023513546213507652,
#  0.022782105952501297,
#  0.030558878555893898,
#  0.0224921777844429,
#  0.031574711203575134,
#  0.024065721780061722,
#  0.02852926030755043,
#  0.024656936526298523,
#  0.026607627049088478,
#  0.03173592686653137,
#  0.024383584037423134,
#  0.035159192979335785,
#  0.0253595020622015,
#  0.034728772938251495,
#  0.024383584037423134,
#  0.027517378330230713,
#  0.05066949874162674,
#  0.02454223483800888,
#  0.017881762236356735,
#  0.027398360893130302,
#  0.020964791998267174,
#  0.028019540011882782,
#  0.029339591041207314,
#  0.03936140239238739,
#  0.025254156440496445,
#  0.024299317970871925,
#  0.02345346473157406,
#  0.026420054957270622,
#  0.030558878555893898,
#  0.03742962330579758,
#  0.018503718078136444,
#  0.02247638627886772,
#  0.03209472447633743,
#  0.028692036867141724,
#  0.025254156440496445,
#  0.024299317970871925,
#  0.026607627049088478,
#  0.02163274772465229,
#  0.02413208968937397,
#  0.025736220180988312,
#  0.020447703078389168,
#  0.02353811077773571,
#  0.025131018832325935,
#  0.018544254824519157,
#  0.02852926030755043,
#  0.03068351186811924,
#  0.030558878555893898,
#  0.0224921777844429,
#  0.02413208968937397,
#  0.020735200494527817,
#  0.025131018832325935,
#  0.019216446205973625,
#  0.031467486172914505,
#  0.027283206582069397,
#  0.026818355545401573,
#  0.03012484312057495,
#  0.03262179717421532,
#  0.02454223483800888,
#  0.02406594716012478,
#  0.020878389477729797,
#  0.025131018832325935,
#  0.01787230558693409,
#  0.026607627049088478,
#  0.02692394331097603,
#  0.026607627049088478,
#  0.02163274772465229,
#  0.024731270968914032,
#  0.04415788874030113,
#  0.025131018832325935,
#  0.01787230558693409,
#  0.02345346473157406,
#  0.02628502994775772,
#  0.03209472447633743,
#  0.03162311017513275,
#  0.026607627049088478,
#  0.031224148347973824,
#  0.020447703078389168,
#  0.029285822063684464,
#  0.027177274227142334,
#  0.019864900037646294,
#  0.026941949501633644,
#  0.031786538660526276,
#  0.02708291821181774,
#  0.025131043046712875,
#  0.020447703078389168,
#  0.03031202405691147,
#  0.023513546213507652,
#  0.01687966287136078]

# %%
# load the best model
regression_head.load_state_dict(torch.load('models/regression_head_best_acc.pth'))
# Out:
# /tmp/ipykernel_145071/847338249.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   regression_head.load_state_dict(torch.load('models/regression_head_best_acc.pth'))
# <All keys matched successfully>

# %%
# prompt_base = '''
# You are a human and there is a robot operating in an office kitchen. The robot are in front of a counter with two closed drawers, a top one and a bottom one. There is also a landfill bin, a recycling bin, and a compost bin.
# On the counter, there is {scence}.
# You says :"{task}".
# Then the robot {action}.
# Does the robot do the right thing?
# '''
import hashlib
regression_head.eval()
def get_confidence(task, pick_obj, relation, target_obj, rnd=0, detail_flag=False):
    prompt = prompt_base.format(task=task, pick_obj=pick_obj, relation=relation, target_obj=target_obj)
    prompt_hash = hashlib.md5(prompt.encode()).hexdigest()
    cache_file_name = f'cache/encode/{prompt_hash}.pkl'
    if Path(cache_file_name).exists():
        with open(cache_file_name, 'rb') as f:
            cls_output = pickle.load(f)
            cls_output = torch.tensor(cls_output).float().to(device)
    else:
        # print(prompt)
        encoding = tokenizer(
            prompt,
            max_length=val_dataset.max_length,
            padding='max_length',
            return_tensors="pt",
        )

        cls_output = encode_model(encoding["input_ids"].to(device), encoding["attention_mask"].to(device)).squeeze(0)
        with open(cache_file_name, 'wb') as f:
            pickle.dump(cls_output.to('cpu').numpy(), f)

    
    outputs = regression_head(torch.tensor(cls_output).float().to(device))

    result = (outputs[0] * (1 - outputs[1]*0.6)).item()
    if rnd:
        target, predictor = rnd_model(cls_output)
        result = result - rnd_loss_fn(target, predictor).item()*rnd
    if detail_flag:
        return {'confidence':result,'s_conf': outputs[0].item(), 's_ambi': outputs[1].item()}
    else:
        return result
    # return {'confidence':result,'s_conf': outputs[0].item(), 's_ambi': outputs[1].item()}
get_confidence('open the top drawer', pick_obj='pcik_obj', relation='relation', target_obj='target_obj', rnd=1)
# Out:
# /tmp/ipykernel_145071/1637865471.py:32: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   outputs = regression_head(torch.tensor(cls_output).float().to(device))
# -0.02825511433184147

# %%
import numpy as np
class ListDict(dict):
    def __getitem__(self, key):
        if key not in self:
            self[key] = []
        return super().__getitem__(key)
def evaluate(scenario_data, return_all=False):


    confidence_with_right = ListDict()
    confidence_without_right = ListDict()
    model_bias_record = ListDict()
    for data in scenario_data:
        if 'result' not in data:
            continue
        # print(data['result'])
        for experiment_name, result in data['result'].items():
            # print(experiment_name)
            bias = result['confidence'] if not result['right'] else 1 - result['confidence']
            model_bias_record[experiment_name].append({
                'index': data['index'],
                'bias': bias
            })
            if result['right']:
                if experiment_name not in confidence_with_right:
                    confidence_with_right[experiment_name] = []
                confidence_with_right[experiment_name].append(float(result['confidence']))
            else:
                if experiment_name not in confidence_without_right:
                    confidence_without_right[experiment_name] = []
                confidence_without_right[experiment_name].append(float(result['confidence']))


# help rate v.s. success rate
    result_with_confidence = ListDict()
    for data in scenario_data:
        if 'result' not in data:
            continue
        for experiment_name, result in data['result'].items():
            result_with_confidence[experiment_name].append((float(result['confidence']), result['right']))
    
    with open('tablet_result/result_with_confidence.pkl', 'wb') as f:
        pickle.dump(result_with_confidence, f)

# 对所有结果进行排序
    for experiment_name in result_with_confidence:
        result_with_confidence[experiment_name].sort(key=lambda x: x[0])

# 不同Help Rate下的Success Rate
    success_rate_conditioned_on_confidence = ListDict()
    for experiment_name in result_with_confidence:
        for hr_percent in range(0, 101, 1):
            success_cache = []
            for ii, res_conf in enumerate(result_with_confidence[experiment_name]):
                if ii < len(result_with_confidence[experiment_name]) * hr_percent / 100:
                    success_cache.append(1)
                elif res_conf[1]:
                    success_cache.append(1)
                else:
                    success_cache.append(0)
            if len(success_cache) > 0:
                success_rate_conditioned_on_confidence[experiment_name].append(np.mean(success_cache))
            else:
                success_rate_conditioned_on_confidence[experiment_name].append(1)
    with open('tablet_result/success_rate_conditioned_on_confidence.pkl', 'wb') as f:
        pickle.dump(success_rate_conditioned_on_confidence, f)
# 均一化 防止初始高成功率对结果的影响
    for experiment_name in success_rate_conditioned_on_confidence:
        # 所有实验数据减去第一个数据和最后一个数据的直线
        success_rate_conditioned_on_confidence[experiment_name] = np.array(success_rate_conditioned_on_confidence[experiment_name])
        minus_data = success_rate_conditioned_on_confidence[experiment_name][-1] - success_rate_conditioned_on_confidence[experiment_name][0]
        minus_data = np.linspace(success_rate_conditioned_on_confidence[experiment_name][0], 1, len(success_rate_conditioned_on_confidence[experiment_name]))
        
        # 所有数据 除以 （1-第一个数据）* 第一个数据
        normal_coff = (1-success_rate_conditioned_on_confidence[experiment_name][0]) * success_rate_conditioned_on_confidence[experiment_name][0]

        success_rate_conditioned_on_confidence[experiment_name] -= minus_data
        # normal_coff = normal_coff * 0.5 * len(success_rate_conditioned_on_confidence[experiment_name])
        success_rate_conditioned_on_confidence[experiment_name] /= normal_coff
    # assert normal_coff > 0

# 面积总和计算
    sr_hr_area = {}
    divider = 0.5 * (len(success_rate_conditioned_on_confidence[experiment_name]) - 1)
    for experiment_name in success_rate_conditioned_on_confidence:
        sr_hr_area[experiment_name] = np.trapz(success_rate_conditioned_on_confidence[experiment_name], dx=1) / divider

    final_result = []
    all_experiments = set(confidence_with_right.keys()) | set(confidence_without_right.keys())
    for experiment_name in all_experiments:
        # print(f'{experiment_name} with right answer: {np.mean(confidence_with_right[experiment_name])}')
        # print(f'{experiment_name} without right answer: {np.mean(confidence_without_right[experiment_name])}')
        final_result.append({
        'experiment_name': experiment_name,
        'confidence_with_right': np.mean(confidence_with_right[experiment_name]),
        'confidence_without_right': np.mean(confidence_without_right[experiment_name]),
        'sr_hr_area': sr_hr_area.get(experiment_name, 0)
        })
        print(experiment_name)
        if 'model0' in experiment_name and not return_all:
            return final_result[-1]
    return final_result

# %%
# add test result to uncertainty dataset

import json, pickle, os
import tqdm.notebook as tqdm

# cot conformal
def process_method(data, rnd, action_model ='conformal'):

    ori_model_output = data[f'{action_model}_output'][0]
    pick_obj = ori_model_output['pick_obj']
    relation = ori_model_output['relation']
    target_obj = ori_model_output['target_obj']
    instruction = data['instruction']
    confidence = get_confidence(instruction, pick_obj, relation, target_obj, rnd=rnd)
    print(f'action: {instruction}\nconfidence: {confidence}')
    model_output = []
    model_output.append({
        'pick_obj': pick_obj,
        'relation': relation,
        'target_obj': target_obj,
        'confidence': confidence
    })
    data[f'model0_output_rnd{rnd}'] = model_output


def process_cached_data(data_index, rnds):
    pickle_path = f"./cache/data{data_index}.pkl"

    if os.path.exists(pickle_path):
        with open(pickle_path, 'rb') as f:
            data = pickle.load(f)
        print('-'*20, f'开始处理新情景[{data["index"]}]', '-'*20)
        try:
            process_method(data, rnd=rnd)
            evaluate_output_confidence1(data)
            # save data to ./cache/data[index].pkl
            with open(f'./cache/data{data["index"]}.pkl', 'wb') as f:
                pickle.dump(data, f)
        except Exception as e:
            raise e
            print('error:', e)

def get_experiment_name(k):
    return k.replace('new_', '').replace('_output','')
# 未聚合情况下各方案正确答案提取
def evaluate_output_confidence1(data):
    def same(s1, s2):
        return s1.lower().strip() == s2.lower().strip()
    data['result'] = {}
    for k,v in data.items():
        if 'output' in k:
            experiment_name = k.replace('_output','')
            data['goal']
            
            data['result'][experiment_name] = {
                    'pick_obj': data[k][0]['pick_obj'],
                    'relation': data[k][0]['relation'],
                    'target_obj': data[k][0]['target_obj'],
                    'confidence': data[k][0]['confidence'],
                    'right': same(data['goal'][0], data[k][0]['pick_obj']) and same(data['goal'][1], data[k][0]['relation']) and same(data['goal'][2], data[k][0]['target_obj'])
                }
            print(f'{experiment_name}: {data['result'][experiment_name]}, {data['goal']}')

rnd_res = {}
rnds = [0,30]
all_data = []
for i in tqdm.trange(301):
    if not os.path.exists(f'./cache/tablet/data{i}.pkl'):
        continue
    with open(f'./cache/tablet/data{i}.pkl', 'rb') as f:
        data = pickle.load(f)
    try:
        for rnd in rnds:
            process_method(data, rnd=rnd)
        evaluate_output_confidence1(data)
        all_data.append(data)
    except Exception as e:
        print('error in', i)
        print(e)
res=evaluate(all_data, return_all=True)
rnd_res = res
print(rnd_res)
# Out:
#   0%|          | 0/301 [00:00<?, ?it/s]
# action: put the blue block to the left of the blue bowl
# confidence: 0.9995329976081848
# action: put the blue block to the left of the blue bowl
# confidence: 0.4757472537457943
# vanilla: {'pick_obj': 'blue block', 'relation': 'left', 'target_obj': 'blue bowl', 'confidence': 1.0, 'right': True}, ['blue block', 'left', 'blue bowl']
# cot: {'pick_obj': 'blue block', 'relation': 'in', 'target_obj': 'blue bowl', 'confidence': 0.6, 'right': False}, ['blue block', 'left', 'blue bowl']
# self_probing: {'pick_obj': 'blue block', 'relation': 'left', 'target_obj': 'blue bowl"', 'confidence': 0.75, 'right': False}, ['blue block', 'left', 'blue bowl']
# self_probing_log: {'pick_obj': 'blue block', 'relation': 'left', 'target_obj': 'blue bowl"', 'confidence': 0.0, 'right': False}, ['blue block', 'left', 'blue bowl']
# multi_step: {'pick_obj': 'blue block', 'relation': 'right of', 'target_obj': 'blue bowl', 'confidence': 0.26880000000000004, 'right': False}, ['blue block', 'left', 'blue bowl']
# top_k: {'pick_obj': 'blue block', 'relation': 'left', 'target_obj': 'blue bowl', 'confidence': 0.7, 'right': True}, ['blue block', 'left', 'blue bowl']
# conformal: {'pick_obj': 'blue block', 'relation': 'left', 'target_obj': 'blue bowl', 'confidence': np.float64(0.22808656403013713), 'right': True}, ['blue block', 'left', 'blue bowl']
# model0_rnd0: {'pick_obj': 'blue block', 'relation': 'left', 'target_obj': 'blue bowl', 'confidence': 0.9995329976081848, 'right': True}, ['blue block', 'left', 'blue bowl']
# model0_rnd30: {'pick_obj': 'blue block', 'relation': 'left', 'target_obj': 'blue bowl', 'confidence': 0.4757472537457943, 'right': True}, ['blue block', 'left', 'blue bowl']
# /tmp/ipykernel_145071/1637865471.py:32: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   outputs = regression_head(torch.tensor(cls_output).float().to(device))
# action: put the block in the blue bowl
# confidence: 0.24490982294082642
# action: put the block in the blue bowl
# confidence: -0.6716469302773476
# vanilla: {'pick_obj': 'blue block', 'relation': 'in', 'target_obj': 'blue bowl', 'confidence': 0.8, 'right': False}, ['green block', 'in', 'blue bowl']
# cot: {'pick_obj': 'blue block', 'relation': 'in', 'target_obj': 'blue bowl', 'confidence': 0.6, 'right': False}, ['green block', 'in', 'blue bowl']
# self_probing: {'pick_obj': 'blue bowl', 'relation': 'in', 'target_obj': 'blue block', 'confidence': 0.6, 'right': False}, ['green block', 'in', 'blue bowl']
# self_probing_log: {'pick_obj': 'blue bowl', 'relation': 'in', 'target_obj': 'blue block', 'confidence': 0.0, 'right': False}, ['green block', 'in', 'blue bowl']
# multi_step: {'pick_obj': 'blue block', 'relation': 'in', 'target_obj': 'blue bowl', 'confidence': 0.48, 'right': False}, ['green block', 'in', 'blue bowl']
# top_k: {'pick_obj': 'blue block', 'relation': 'in', 'target_obj': 'blue bowl', 'confidence': 0.9, 'right': False}, ['green block', 'in', 'blue bowl']
# conformal: {'pick_obj': 'blue block', 'relation': 'in', 'target_obj': 'blue bowl', 'confidence': np.float64(0.2302395006558244), 'right': False}, ['green block', 'in', 'blue bowl']
# model0_rnd0: {'pick_obj': 'blue block', 'relation': 'in', 'target_obj': 'blue bowl', 'confidence': 0.24490982294082642, 'right': False}, ['green block', 'in', 'blue bowl']
# model0_rnd30: {'pick_obj': 'blue block', 'relation': 'in', 'target_obj': 'blue bowl', 'confidence': -0.6716469302773476, 'right': False}, ['green block', 'in', 'blue bowl']
# action: put the yellow block to the back of the yellow bowl
# confidence: 0.9950653314590454
# action: put the yellow block to the back of the yellow bowl
# confidence: 0.08757299184799194
# conformal: {'pick_obj': 'yellow block', 'relation': 'back', 'target_obj': 'yellow bowl', 'confidence': np.float64(0.2549511371317791), 'right': True}, ['yellow block', 'back', 'yellow bowl']
# vanilla: {'pick_obj': 'yellow block', 'relation': 'back', 'target_obj': 'yellow bowl', 'confidence': 1.0, 'right': True}, ['yellow block', 'back', 'yellow bowl']
# cot: {'pick_obj': 'yellow block', 'relation': 'to the back of', 'target_obj': 'yellow bowl', 'confidence': 0.6, 'right': False}, ['yellow block', 'back', 'yellow bowl']
# self_probing: {'pick_obj': 'yellow block', 'relation': 'back', 'target_obj': 'yellow bowl', 'confidence': 0.7, 'right': True}, ['yellow block', 'back', 'yellow bowl']
# self_probing_log: {'pick_obj': 'yellow block', 'relation': 'back', 'target_obj': 'yellow bowl', 'confidence': 0.0, 'right': True}, ['yellow block', 'back', 'yellow bowl']
# multi_step: {'pick_obj': 'yellow block', 'relation': 'back', 'target_obj': 'yellow bowl', 'confidence': 0.0672, 'right': True}, ['yellow block', 'back', 'yellow bowl']
# top_k: {'pick_obj': 'yellow block', 'relation': 'back', 'target_obj': 'yellow bowl', 'confidence': 0.85, 'right': True}, ['yellow block', 'back', 'yellow bowl']
# model0_rnd0: {'pick_obj': 'yellow block', 'relation': 'back', 'target_obj': 'yellow bowl', 'confidence': 0.9950653314590454, 'right': True}, ['yellow block', 'back', 'yellow bowl']
# model0_rnd30: {'pick_obj': 'yellow block', 'relation': 'back', 'target_obj': 'yellow bowl', 'confidence': 0.08757299184799194, 'right': True}, ['yellow block', 'back', 'yellow bowl']
# action: put the green block in the bowl
# confidence: 0.33259809017181396
# action: put the green block in the bowl
# confidence: -0.24855725467205048
# vanilla: {'pick_obj': 'green block', 'relation': 'in', 'target_obj': 'green bowl', 'confidence': 0.8, 'right': True}, ['green block', 'in', 'green bowl']
# cot: {'pick_obj': 'green block', 'relation': 'in', 'target_obj': 'bowl', 'confidence': 0.5, 'right': False}, ['green block', 'in', 'green bowl']
# self_probing: {'pick_obj': 'green bowl', 'relation': 'in', 'target_obj': 'green block"', 'confidence': 0.75, 'right': False}, ['green block', 'in', 'green bowl']
# self_probing_log: {'pick_obj': 'green bowl', 'relation': 'in', 'target_obj': 'green block"', 'confidence': 0.0, 'right': False}, ['green block', 'in', 'green bowl']
# multi_step: {'pick_obj': 'green block', 'relation': 'in', 'target_obj': 'green bowl', 'confidence': 0.32845679999999994, 'right': True}, ['green block', 'in', 'green bowl']
# top_k: {'pick_obj': 'green block', 'relation': 'in', 'target_obj': 'green bowl', 'confidence': 0.8, 'right': True}, ['green block', 'in', 'green bowl']
# conformal: {'pick_obj': 'green block', 'relation': 'in', 'target_obj': 'green bowl', 'confidence': np.float64(0.22084681666167794), 'right': True}, ['green block', 'in', 'green bowl']
# model0_rnd0: {'pick_obj': 'green block', 'relation': 'in', 'target_obj': 'green bowl', 'confidence': 0.33259809017181396, 'right': True}, ['green block', 'in', 'green bowl']
# model0_rnd30: {'pick_obj': 'green block', 'relation': 'in', 'target_obj': 'green bowl', 'confidence': -0.24855725467205048, 'right': True}, ['green block', 'in', 'green bowl']
# action: put the blue block close to the blue bowl
# confidence: 0.0011538832914084196
# action: put the blue block close to the blue bowl
# confidence: -1.2843886644113809
# vanilla: {'pick_obj': 'blue block', 'relation': 'right', 'target_obj': 'blue bowl', 'confidence': 1.0, 'right': False}, ['blue block', 'back', 'blue bowl']
# cot: {'pick_obj': 'blue block', 'relation': 'near', 'target_obj': 'blue bowl', 'confidence': 0.8, 'right': False}, ['blue block', 'back', 'blue bowl']
# self_probing: {'pick_obj': 'blue block', 'relation': 'right', 'target_obj': 'blue bowl', 'confidence': 0.6, 'right': False}, ['blue block', 'back', 'blue bowl']
# self_probing_log: {'pick_obj': 'blue block', 'relation': 'right', 'target_obj': 'blue bowl', 'confidence': 0.0, 'right': False}, ['blue block', 'back', 'blue bowl']
# multi_step: {'pick_obj': 'blue block', 'relation': 'right', 'target_obj': 'blue bowl', 'confidence': 0.5697720000000001, 'right': False}, ['blue block', 'back', 'blue bowl']
# top_k: {'pick_obj': 'blue block', 'relation': 'right', 'target_obj': 'blue bowl', 'confidence': 0.8, 'right': False}, ['blue block', 'back', 'blue bowl']
# conformal: {'pick_obj': 'blue block', 'relation': 'front', 'target_obj': 'blue bowl', 'confidence': np.float64(0.2194945587004158), 'right': False}, ['blue block', 'back', 'blue bowl']
# model0_rnd0: {'pick_obj': 'blue block', 'relation': 'front', 'target_obj': 'blue bowl', 'confidence': 0.0011538832914084196, 'right': False}, ['blue block', 'back', 'blue bowl']
# model0_rnd30: {'pick_obj': 'blue block', 'relation': 'front', 'target_obj': 'blue bowl', 'confidence': -1.2843886644113809, 'right': False}, ['blue block', 'back', 'blue bowl']
# action: put the green block in the bowl
# confidence: 0.007123237941414118
# action: put the green block in the bowl
# confidence: -0.789765642490238
# vanilla: {'pick_obj': 'green block', 'relation': 'in', 'target_obj': 'green bowl', 'confidence': 1.0, 'right': True}, ['green block', 'in', 'green bowl']
# cot: {'pick_obj': 'green block', 'relation': 'in', 'target_obj': 'green bowl', 'confidence': 0.8, 'right': True}, ['green block', 'in', 'green bowl']
# self_probing: {'pick_obj': 'green block', 'relation': 'in', 'target_obj': 'green bowl', 'confidence': 0.5, 'right': True}, ['green block', 'in', 'green bowl']
# self_probing_log: {'pick_obj': 'green block', 'relation': 'in', 'target_obj': 'green bowl', 'confidence': 0.0, 'right': True}, ['green block', 'in', 'green bowl']
# multi_step: {'pick_obj': 'green block', 'relation': 'in', 'target_obj': 'green bowl', 'confidence': 0.22982400000000003, 'right': True}, ['green block', 'in', 'green bowl']
# top_k: {'pick_obj': 'green block', 'relation': 'in', 'target_obj': 'green bowl', 'confidence': 0.6, 'right': True}, ['green block', 'in', 'green bowl']
# conformal: {'pick_obj': 'green block', 'relation': 'in', 'target_obj': 'blue bowl', 'confidence': np.float64(0.23178192279978146), 'right': False}, ['green block', 'in', 'green bowl']
# model0_rnd0: {'pick_obj': 'green block', 'relation': 'in', 'target_obj': 'blue bowl', 'confidence': 0.007123237941414118, 'right': False}, ['green block', 'in', 'green bowl']
# model0_rnd30: {'pick_obj': 'green block', 'relation': 'in', 'target_obj': 'blue bowl', 'confidence': -0.789765642490238, 'right': False}, ['green block', 'in', 'green bowl']
# action: put the yellow block in the bowl
# confidence: 0.31083354353904724
# action: put the yellow block in the bowl
# confidence: -0.4381413608789444
# vanilla: {'pick_obj': 'yellow block', 'relation': 'in', 'target_obj': 'yellow bowl', 'confidence': 0.8, 'right': True}, ['yellow block', 'in', 'yellow bowl']
# cot: {'pick_obj': 'yellow block', 'relation': 'in', 'target_obj': 'yellow bowl', 'confidence': 0.8, 'right': True}, ['yellow block', 'in', 'yellow bowl']
# self_probing: {'pick_obj': 'yellow block', 'relation': 'in', 'target_obj': 'yellow bowl', 'confidence': 0.8, 'right': True}, ['yellow block', 'in', 'yellow bowl']
# self_probing_log: {'pick_obj': 'yellow block', 'relation': 'in', 'target_obj': 'yellow bowl', 'confidence': 0.0, 'right': True}, ['yellow block', 'in', 'yellow bowl']
# multi_step: {'pick_obj': 'yellow block', 'relation': 'in', 'target_obj': 'yellow bowl', 'confidence': 0.4788, 'right': True}, ['yellow block', 'in', 'yellow bowl']
# top_k: {'pick_obj': 'yellow block', 'relation': 'in', 'target_obj': 'yellow bowl', 'confidence': 0.8, 'right': True}, ['yellow block', 'in', 'yellow bowl']
# conformal: {'pick_obj': 'yellow block', 'relation': 'in', 'target_obj': 'yellow bowl', 'confidence': np.float64(0.21898068570923085), 'right': True}, ['yellow block', 'in', 'yellow bowl']
# model0_rnd0: {'pick_obj': 'yellow block', 'relation': 'in', 'target_obj': 'yellow bowl', 'confidence': 0.31083354353904724, 'right': True}, ['yellow block', 'in', 'yellow bowl']
# model0_rnd30: {'pick_obj': 'yellow block', 'relation': 'in', 'target_obj': 'yellow bowl', 'confidence': -0.4381413608789444, 'right': True}, ['yellow block', 'in', 'yellow bowl']
# action: put the block in the green bowl
# confidence: 0.029461117461323738
# action: put the block in the green bowl
# confidence: -0.7857862543314695
# vanilla: {'pick_obj': 'green block', 'relation': 'in', 'target_obj': 'green bowl', 'confidence': 1.0, 'right': False}, ['blue block', 'in', 'green bowl']
# cot: {'pick_obj': 'green block', 'relation': 'in', 'target_obj': 'green bowl', 'confidence': 0.8, 'right': False}, ['blue block', 'in', 'green bowl']
# self_probing: {'pick_obj': 'green block', 'relation': 'in', 'target_obj': 'green bowl', 'confidence': 0.75, 'right': False}, ['blue block', 'in', 'green bowl']
# self_probing_log: {'pick_obj': 'green block', 'relation': 'in', 'target_obj': 'green bowl', 'confidence': 0.0, 'right': False}, ['blue block', 'in', 'green bowl']
# multi_step: {'pick_obj': 'blue block', 'relation': 'in', 'target_obj': 'green bowl', 'confidence': 0.67032, 'right': True}, ['blue block', 'in', 'green bowl']
# top_k: {'pick_obj': 'green block', 'relation': 'in', 'target_obj': 'green bowl', 'confidence': 0.6, 'right': False}, ['blue block', 'in', 'green bowl']
# conformal: {'pick_obj': 'yellow block', 'relation': 'in', 'target_obj': 'green bowl', 'confidence': np.float64(0.22680164563982388), 'right': False}, ['blue block', 'in', 'green bowl']
# model0_rnd0: {'pick_obj': 'yellow block', 'relation': 'in', 'target_obj': 'green bowl', 'confidence': 0.029461117461323738, 'right': False}, ['blue block', 'in', 'green bowl']
# model0_rnd30: {'pick_obj': 'yellow block', 'relation': 'in', 'target_obj': 'green bowl', 'confidence': -0.7857862543314695, 'right': False}, ['blue block', 'in', 'green bowl']
# action: put the blue block close to the blue bowl
# confidence: 0.012282336130738258
# action: put the blue block close to the blue bowl
# confidence: -0.7773871552199125
# vanilla: {'pick_obj': 'blue block', 'relation': 'left', 'target_obj': 'blue bowl', 'confidence': 0.8, 'right': True}, ['blue block', 'left', 'blue bowl']
# cot: {'pick_obj': 'blue block', 'relation': 'right', 'target_obj': 'blue bowl', 'confidence': 0.9, 'right': False}, ['blue block', 'left', 'blue bowl']
# self_probing: {'pick_obj': 'blue block', 'relation': 'right', 'target_obj': 'blue bowl', 'confidence': 0.75, 'right': False}, ['blue block', 'left', 'blue bowl']
# self_probing_log: {'pick_obj': 'blue block', 'relation': 'right', 'target_obj': 'blue bowl', 'confidence': 0.0, 'right': False}, ['blue block', 'left', 'blue bowl']
# multi_step: {'pick_obj': 'blue block', 'relation': 'left', 'target_obj': 'blue bowl', 'confidence': 0.00040320000000000004, 'right': True}, ['blue block', 'left', 'blue bowl']
# top_k: {'pick_obj': 'blue block', 'relation': 'right', 'target_obj': 'blue bowl', 'confidence': 0.8, 'right': False}, ['blue block', 'left', 'blue bowl']
# conformal: {'pick_obj': 'blue block', 'relation': 'left', 'target_obj': 'blue bowl', 'confidence': np.float64(0.21222882118370767), 'right': True}, ['blue block', 'left', 'blue bowl']
# model0_rnd0: {'pick_obj': 'blue block', 'relation': 'left', 'target_obj': 'blue bowl', 'confidence': 0.012282336130738258, 'right': True}, ['blue block', 'left', 'blue bowl']
# model0_rnd30: {'pick_obj': 'blue block', 'relation': 'left', 'target_obj': 'blue bowl', 'confidence': -0.7773871552199125, 'right': True}, ['blue block', 'left', 'blue bowl']
# action: put the block in the green bowl
# confidence: 0.042048387229442596
# action: put the block in the green bowl
# confidence: -0.5717292129993439
# vanilla: {'pick_obj': 'green block', 'relation': 'in', 'target_obj': 'green bowl', 'confidence': 1.0, 'right': True}, ['green block', 'in', 'green bowl']
# cot: {'pick_obj': 'green block', 'relation': 'in', 'target_obj': 'green bowl', 'confidence': 0.6, 'right': True}, ['green block', 'in', 'green bowl']
# self_probing: {'pick_obj': 'green block', 'relation': 'in', 'target_obj': 'green bowl', 'confidence': 0.8, 'right': True}, ['green block', 'in', 'green bowl']
# self_probing_log: {'pick_obj': 'green block', 'relation': 'in', 'target_obj': 'green bowl', 'confidence': 0.0, 'right': True}, ['green block', 'in', 'green bowl']
# multi_step: {'pick_obj': 'green block', 'relation': 'in', 'target_obj': 'green bowl', 'confidence': 0.66, 'right': True}, ['green block', 'in', 'green bowl']
# top_k: {'pick_obj': 'green block', 'relation': 'in', 'target_obj': 'green bowl', 'confidence': 0.8, 'right': True}, ['green block', 'in', 'green bowl']
# conformal: {'pick_obj': 'blue block', 'relation': 'in', 'target_obj': 'green bowl', 'confidence': np.float64(0.21801826810560426), 'right': False}, ['green block', 'in', 'green bowl']
# model0_rnd0: {'pick_obj': 'blue block', 'relation': 'in', 'target_obj': 'green bowl', 'confidence': 0.042048387229442596, 'right': False}, ['green block', 'in', 'green bowl']
# model0_rnd30: {'pick_obj': 'blue block', 'relation': 'in', 'target_obj': 'green bowl', 'confidence': -0.5717292129993439, 'right': False}, ['green block', 'in', 'green bowl']
# action: put the green block to the back of the green bowl
# confidence: 0.9945957660675049
# action: put the green block to the back of the green bowl
# confidence: 0.1390351839363575
# vanilla: {'pick_obj': 'green block', 'relation': 'back', 'target_obj': 'green bowl', 'confidence': 0.9, 'right': True}, ['green block', 'back', 'green bowl']
# cot: {'pick_obj': 'green block', 'relation': 'behind', 'target_obj': 'green bowl', 'confidence': 1.0, 'right': False}, ['green block', 'back', 'green bowl']
# self_probing: {'pick_obj': 'green block', 'relation': 'back', 'target_obj': 'green bowl', 'confidence': 0.8, 'right': True}, ['green block', 'back', 'green bowl']
# self_probing_log: {'pick_obj': 'green block', 'relation': 'back', 'target_obj': 'green bowl', 'confidence': 0.0, 'right': True}, ['green block', 'back', 'green bowl']
# multi_step: {'pick_obj': 'green block', 'relation': 'back', 'target_obj': 'green bowl', 'confidence': 0.43091999999999997, 'right': True}, ['green block', 'back', 'green bowl']
# top_k: {'pick_obj': 'green block,', 'relation': 'in,', 'target_obj': 'green bowl', 'confidence': 0.8, 'right': False}, ['green block', 'back', 'green bowl']
# conformal: {'pick_obj': 'green block', 'relation': 'back', 'target_obj': 'green bowl', 'confidence': np.float64(0.2726324271096229), 'right': True}, ['green block', 'back', 'green bowl']
# model0_rnd0: {'pick_obj': 'green block', 'relation': 'back', 'target_obj': 'green bowl', 'confidence': 0.9945957660675049, 'right': True}, ['green block', 'back', 'green bowl']
# model0_rnd30: {'pick_obj': 'green block', 'relation': 'back', 'target_obj': 'green bowl', 'confidence': 0.1390351839363575, 'right': True}, ['green block', 'back', 'green bowl']
# action: put the yellow block in the bowl
# confidence: 0.31083354353904724
# action: put the yellow block in the bowl
# confidence: -0.4381413608789444
# vanilla: {'pick_obj': 'yellow block', 'relation': 'in', 'target_obj': 'yellow bowl', 'confidence': 1.0, 'right': True}, ['yellow block', 'in', 'yellow bowl']
# cot: {'pick_obj': 'yellow block', 'relation': 'in', 'target_obj': 'yellow bowl', 'confidence': 0.6, 'right': True}, ['yellow block', 'in', 'yellow bowl']
# self_probing: {'pick_obj': 'yellow block', 'relation': 'in', 'target_obj': 'yellow bowl', 'confidence': 0.75, 'right': True}, ['yellow block', 'in', 'yellow bowl']
# self_probing_log: {'pick_obj': 'yellow block', 'relation': 'in', 'target_obj': 'yellow bowl', 'confidence': 0.0, 'right': True}, ['yellow block', 'in', 'yellow bowl']
# multi_step: {'pick_obj': 'yellow block', 'relation': 'in', 'target_obj': 'yellow bowl', 'confidence': 0.770868, 'right': True}, ['yellow block', 'in', 'yellow bowl']
# top_k: {'pick_obj': 'yellow block', 'relation': 'in', 'target_obj': 'yellow bowl', 'confidence': 0.8, 'right': True}, ['yellow block', 'in', 'yellow bowl']
# conformal: {'pick_obj': 'yellow block', 'relation': 'in', 'target_obj': 'yellow bowl', 'confidence': np.float64(0.2205509199412362), 'right': True}, ['yellow block', 'in', 'yellow bowl']
# model0_rnd0: {'pick_obj': 'yellow block', 'relation': 'in', 'target_obj': 'yellow bowl', 'confidence': 0.31083354353904724, 'right': True}, ['yellow block', 'in', 'yellow bowl']
# model0_rnd30: {'pick_obj': 'yellow block', 'relation': 'in', 'target_obj': 'yellow bowl', 'confidence': -0.4381413608789444, 'right': True}, ['yellow block', 'in', 'yellow bowl']
# action: put the blue block in the blue bowl
# confidence: 0.9771498441696167
# action: put the blue block in the blue bowl
# confidence: 0.019227057695388794
# vanilla: {'pick_obj': 'blue block', 'relation': 'in', 'target_obj': 'blue bowl', 'confidence': 0.9, 'right': True}, ['blue block', 'in', 'blue bowl']
# cot: {'pick_obj': 'blue block', 'relation': 'in', 'target_obj': 'blue bowl', 'confidence': 1.0, 'right': True}, ['blue block', 'in', 'blue bowl']
# self_probing: {'pick_obj': 'blue block', 'relation': 'in', 'target_obj': 'blue bowl', 'confidence': 0.8, 'right': True}, ['blue block', 'in', 'blue bowl']
# self_probing_log: {'pick_obj': 'blue block', 'relation': 'in', 'target_obj': 'blue bowl', 'confidence': 0.0, 'right': True}, ['blue block', 'in', 'blue bowl']
# multi_step: {'pick_obj': 'blue block', 'relation': 'in', 'target_obj': 'blue bowl', 'confidence': 0.55233, 'right': True}, ['blue block', 'in', 'blue bowl']
# top_k: {'pick_obj': 'blue block', 'relation': 'in', 'target_obj': 'blue bowl', 'confidence': 0.9, 'right': True}, ['blue block', 'in', 'blue bowl']
# conformal: {'pick_obj': 'blue block', 'relation': 'in', 'target_obj': 'blue bowl', 'confidence': np.float64(0.27357941263463675), 'right': True}, ['blue block', 'in', 'blue bowl']
# model0_rnd0: {'pick_obj': 'blue block', 'relation': 'in', 'target_obj': 'blue bowl', 'confidence': 0.9771498441696167, 'right': True}, ['blue block', 'in', 'blue bowl']
# model0_rnd30: {'pick_obj': 'blue block', 'relation': 'in', 'target_obj': 'blue bowl', 'confidence': 0.019227057695388794, 'right': True}, ['blue block', 'in', 'blue bowl']
# action: put the yellow block in the bowl
# confidence: 0.31083354353904724
# action: put the yellow block in the bowl
# confidence: -0.4381413608789444
# vanilla: {'pick_obj': 'yellow block', 'relation': 'in', 'target_obj': 'yellow bowl', 'confidence': 0.8, 'right': False}, ['yellow block', 'in', 'green bowl']
# cot: {'pick_obj': 'yellow block', 'relation': 'in', 'target_obj': 'yellow bowl', 'confidence': 1.0, 'right': False}, ['yellow block', 'in', 'green bowl']
# self_probing: {'pick_obj': 'yellow block', 'relation': 'in', 'target_obj': 'yellow bowl', 'confidence': 0.75, 'right': False}, ['yellow block', 'in', 'green bowl']
# self_probing_log: {'pick_obj': 'yellow block', 'relation': 'in', 'target_obj': 'yellow bowl', 'confidence': 0.0, 'right': False}, ['yellow block', 'in', 'green bowl']
# multi_step: {'pick_obj': 'yellow block', 'relation': 'in', 'target_obj': 'yellow bowl', 'confidence': 0.8379, 'right': False}, ['yellow block', 'in', 'green bowl']
# top_k: {'pick_obj': 'yellow block', 'relation': 'in', 'target_obj': 'yellow bowl', 'confidence': 0.85, 'right': False}, ['yellow block', 'in', 'green bowl']
# conformal: {'pick_obj': 'yellow block', 'relation': 'in', 'target_obj': 'yellow bowl', 'confidence': np.float64(0.2129588426452515), 'right': False}, ['yellow block', 'in', 'green bowl']
# model0_rnd0: {'pick_obj': 'yellow block', 'relation': 'in', 'target_obj': 'yellow bowl', 'confidence': 0.31083354353904724, 'right': False}, ['yellow block', 'in', 'green bowl']
# model0_rnd30: {'pick_obj': 'yellow block', 'relation': 'in', 'target_obj': 'yellow bowl', 'confidence': -0.4381413608789444, 'right': False}, ['yellow block', 'in', 'green bowl']
# action: put the block in the green bowl
# confidence: 0.042048387229442596
# action: put the block in the green bowl
# confidence: -0.5717292129993439
# vanilla: {'pick_obj': 'green block', 'relation': 'in', 'target_obj': 'green bowl', 'confidence': 1.0, 'right': True}, ['green block', 'in', 'green bowl']
# cot: {'pick_obj': 'green block', 'relation': 'in', 'target_obj': 'green bowl', 'confidence': 0.8, 'right': True}, ['green block', 'in', 'green bowl']
# self_probing: {'pick_obj': 'green block', 'relation': 'in', 'target_obj': 'green bowl', 'confidence': 0.7, 'right': True}, ['green block', 'in', 'green bowl']
# self_probing_log: {'pick_obj': 'green block', 'relation': 'in', 'target_obj': 'green bowl', 'confidence': 0.0, 'right': True}, ['green block', 'in', 'green bowl']
# multi_step: {'pick_obj': 'green block', 'relation': 'in', 'target_obj': 'green bowl', 'confidence': 0.534888, 'right': True}, ['green block', 'in', 'green bowl']
# top_k: {'pick_obj': 'green block', 'relation': 'in', 'target_obj': 'green bowl', 'confidence': 0.6, 'right': True}, ['green block', 'in', 'green bowl']
# conformal: {'pick_obj': 'blue block', 'relation': 'in', 'target_obj': 'green bowl', 'confidence': np.float64(0.21535075235130294), 'right': False}, ['green block', 'in', 'green bowl']
# model0_rnd0: {'pick_obj': 'blue block', 'relation': 'in', 'target_obj': 'green bowl', 'confidence': 0.042048387229442596, 'right': False}, ['green block', 'in', 'green bowl']
# model0_rnd30: {'pick_obj': 'blue block', 'relation': 'in', 'target_obj': 'green bowl', 'confidence': -0.5717292129993439, 'right': False}, ['green block', 'in', 'green bowl']
# action: put the yellow block in the bowl
# confidence: 0.31083354353904724
# action: put the yellow block in the bowl
# confidence: -0.4381413608789444
# vanilla: {'pick_obj': 'yellow block', 'relation': 'in', 'target_obj': 'yellow bowl', 'confidence': 0.8, 'right': False}, ['yellow block', 'in', 'green bowl']
# cot: {'pick_obj': 'yellow block', 'relation': 'in', 'target_obj': 'yellow bowl', 'confidence': 0.8, 'right': False}, ['yellow block', 'in', 'green bowl']
# self_probing: {'pick_obj': 'yellow block', 'relation': 'in', 'target_obj': 'yellow bowl', 'confidence': 0.5, 'right': False}, ['yellow block', 'in', 'green bowl']
# self_probing_log: {'pick_obj': 'yellow block', 'relation': 'in', 'target_obj': 'yellow bowl', 'confidence': 0.0, 'right': False}, ['yellow block', 'in', 'green bowl']
# multi_step: {'pick_obj': 'yellow block', 'relation': 'in', 'target_obj': 'yellow bowl', 'confidence': 0.7200000000000001, 'right': False}, ['yellow block', 'in', 'green bowl']
# top_k: {'pick_obj': 'yellow block', 'relation': 'in', 'target_obj': 'yellow bowl', 'confidence': 0.8, 'right': False}, ['yellow block', 'in', 'green bowl']
# conformal: {'pick_obj': 'yellow block', 'relation': 'in', 'target_obj': 'yellow bowl', 'confidence': np.float64(0.21787867864423105), 'right': False}, ['yellow block', 'in', 'green bowl']
# model0_rnd0: {'pick_obj': 'yellow block', 'relation': 'in', 'target_obj': 'yellow bowl', 'confidence': 0.31083354353904724, 'right': False}, ['yellow block', 'in', 'green bowl']
# model0_rnd30: {'pick_obj': 'yellow block', 'relation': 'in', 'target_obj': 'yellow bowl', 'confidence': -0.4381413608789444, 'right': False}, ['yellow block', 'in', 'green bowl']
# action: put the green block in the green bowl
# confidence: 0.9964324235916138
# action: put the green block in the green bowl
# confidence: 0.05247411131858826
# vanilla: {'pick_obj': 'green block', 'relation': 'in', 'target_obj': 'green bowl', 'confidence': 1.0, 'right': True}, ['green block', 'in', 'green bowl']
# cot: {'pick_obj': 'green block', 'relation': 'in', 'target_obj': 'green bowl', 'confidence': 1.0, 'right': True}, ['green block', 'in', 'green bowl']
# self_probing: {'pick_obj': 'green block', 'relation': 'in', 'target_obj': 'green bowl', 'confidence': 0.8, 'right': True}, ['green block', 'in', 'green bowl']
# self_probing_log: {'pick_obj': 'green block', 'relation': 'in', 'target_obj': 'green bowl', 'confidence': 0.0, 'right': True}, ['green block', 'in', 'green bowl']
# multi_step: {'pick_obj': 'green block', 'relation': 'in', 'target_obj': 'green bowl', 'confidence': 0.829521, 'right': True}, ['green block', 'in', 'green bowl']
# top_k: {'pick_obj': 'green block', 'relation': 'in', 'target_obj': 'green bowl', 'confidence': 0.8, 'right': True}, ['green block', 'in', 'green bowl']
# conformal: {'pick_obj': 'green block', 'relation': 'in', 'target_obj': 'green bowl', 'confidence': np.float64(0.22271996795749258), 'right': True}, ['green block', 'in', 'green bowl']
# model0_rnd0: {'pick_obj': 'green block', 'relation': 'in', 'target_obj': 'green bowl', 'confidence': 0.9964324235916138, 'right': True}, ['green block', 'in', 'green bowl']
# model0_rnd30: {'pick_obj': 'green block', 'relation': 'in', 'target_obj': 'green bowl', 'confidence': 0.05247411131858826, 'right': True}, ['green block', 'in', 'green bowl']
# action: put the block in the blue bowl
# confidence: 0.24490982294082642
# action: put the block in the blue bowl
# confidence: -0.6716469302773476
# vanilla: {'pick_obj': 'blue block', 'relation': 'in', 'target_obj': 'blue bowl', 'confidence': 1.0, 'right': False}, ['green block', 'in', 'blue bowl']
# cot: {'pick_obj': 'green block', 'relation': 'in', 'target_obj': 'blue bowl', 'confidence': 0.2, 'right': True}, ['green block', 'in', 'blue bowl']
# self_probing: {'pick_obj': 'blue block', 'relation': 'in', 'target_obj': 'blue bowl', 'confidence': 0.8, 'right': False}, ['green block', 'in', 'blue bowl']
# self_probing_log: {'pick_obj': 'blue block', 'relation': 'in', 'target_obj': 'blue bowl', 'confidence': 0.0, 'right': False}, ['green block', 'in', 'blue bowl']
# multi_step: {'pick_obj': 'green block', 'relation': 'in', 'target_obj': 'blue bowl', 'confidence': 0.13406400000000002, 'right': True}, ['green block', 'in', 'blue bowl']
# top_k: {'pick_obj': 'blue block', 'relation': 'in', 'target_obj': 'blue bowl', 'confidence': 0.6, 'right': False}, ['green block', 'in', 'blue bowl']
# conformal: {'pick_obj': 'blue block', 'relation': 'in', 'target_obj': 'blue bowl', 'confidence': np.float64(0.23620911348685353), 'right': False}, ['green block', 'in', 'blue bowl']
# model0_rnd0: {'pick_obj': 'blue block', 'relation': 'in', 'target_obj': 'blue bowl', 'confidence': 0.24490982294082642, 'right': False}, ['green block', 'in', 'blue bowl']
# model0_rnd30: {'pick_obj': 'blue block', 'relation': 'in', 'target_obj': 'blue bowl', 'confidence': -0.6716469302773476, 'right': False}, ['green block', 'in', 'blue bowl']
# action: put the yellow block in the yellow bowl
# confidence: 0.9955459237098694
# action: put the yellow block in the yellow bowl
# confidence: 0.020084619522094727
# vanilla: {'pick_obj': 'yellow block', 'relation': 'in', 'target_obj': 'yellow bowl', 'confidence': 1.0, 'right': True}, ['yellow block', 'in', 'yellow bowl']
# cot: {'pick_obj': 'yellow block', 'relation': 'in', 'target_obj': 'yellow bowl', 'confidence': 0.5, 'right': True}, ['yellow block', 'in', 'yellow bowl']
# self_probing: {'pick_obj': 'yellow block', 'relation': 'in', 'target_obj': 'yellow bowl', 'confidence': 0.95, 'right': True}, ['yellow block', 'in', 'yellow bowl']
# self_probing_log: {'pick_obj': 'yellow block', 'relation': 'in', 'target_obj': 'yellow bowl', 'confidence': 0.0, 'right': True}, ['yellow block', 'in', 'yellow bowl']
# multi_step: {'pick_obj': 'yellow block', 'relation': 'in', 'target_obj': 'yellow bowl', 'confidence': 0.7200000000000001, 'right': True}, ['yellow block', 'in', 'yellow bowl']
# top_k: {'pick_obj': 'yellow block', 'relation': 'in', 'target_obj': 'yellow bowl', 'confidence': 0.8, 'right': True}, ['yellow block', 'in', 'yellow bowl']
# conformal: {'pick_obj': 'yellow block', 'relation': 'in', 'target_obj': 'yellow bowl', 'confidence': np.float64(0.21877084258131047), 'right': True}, ['yellow block', 'in', 'yellow bowl']
# model0_rnd0: {'pick_obj': 'yellow block', 'relation': 'in', 'target_obj': 'yellow bowl', 'confidence': 0.9955459237098694, 'right': True}, ['yellow block', 'in', 'yellow bowl']
# model0_rnd30: {'pick_obj': 'yellow block', 'relation': 'in', 'target_obj': 'yellow bowl', 'confidence': 0.020084619522094727, 'right': True}, ['yellow block', 'in', 'yellow bowl']
# action: put the yellow block in the bowl
# confidence: 0.02410079352557659
# action: put the yellow block in the bowl
# confidence: -0.9006237331777811
# vanilla: {'pick_obj': 'yellow block', 'relation': 'in', 'target_obj': 'yellow bowl', 'confidence': 1.0, 'right': False}, ['yellow block', 'in', 'blue bowl']
# cot: {'pick_obj': 'yellow block', 'relation': 'in', 'target_obj': 'yellow bowl', 'confidence': 0.8, 'right': False}, ['yellow block', 'in', 'blue bowl']
# self_probing: {'pick_obj': 'yellow block', 'relation': 'in', 'target_obj': 'yellow bowl', 'confidence': 0.8, 'right': False}, ['yellow block', 'in', 'blue bowl']
# self_probing_log: {'pick_obj': 'yellow block', 'relation': 'in', 'target_obj': 'yellow bowl', 'confidence': 0.0, 'right': False}, ['yellow block', 'in', 'blue bowl']
# multi_step: {'pick_obj': 'yellow block', 'relation': 'in', 'target_obj': 'yellow bowl', 'confidence': 0.6703884, 'right': False}, ['yellow block', 'in', 'blue bowl']
# top_k: {'pick_obj': 'yellow block', 'relation': 'in', 'target_obj': 'yellow bowl', 'confidence': 0.9, 'right': False}, ['yellow block', 'in', 'blue bowl']
# conformal: {'pick_obj': 'yellow block', 'relation': 'in', 'target_obj': 'green bowl', 'confidence': np.float64(0.21383120984218681), 'right': False}, ['yellow block', 'in', 'blue bowl']
# model0_rnd0: {'pick_obj': 'yellow block', 'relation': 'in', 'target_obj': 'green bowl', 'confidence': 0.02410079352557659, 'right': False}, ['yellow block', 'in', 'blue bowl']
# model0_rnd30: {'pick_obj': 'yellow block', 'relation': 'in', 'target_obj': 'green bowl', 'confidence': -0.9006237331777811, 'right': False}, ['yellow block', 'in', 'blue bowl']
# action: put the green block in the green bowl
# confidence: 0.9964324235916138
# action: put the green block in the green bowl
# confidence: 0.05247411131858826
# vanilla: {'pick_obj': 'green block', 'relation': 'in', 'target_obj': 'green bowl', 'confidence': 1.0, 'right': True}, ['green block', 'in', 'green bowl']
# cot: {'pick_obj': 'green block', 'relation': 'in', 'target_obj': 'green bowl', 'confidence': 1.0, 'right': True}, ['green block', 'in', 'green bowl']
# self_probing: {'pick_obj': 'green block', 'relation': 'in', 'target_obj': 'green bowl', 'confidence': 0.7, 'right': True}, ['green block', 'in', 'green bowl']
# self_probing_log: {'pick_obj': 'green block', 'relation': 'in', 'target_obj': 'green bowl', 'confidence': 0.0, 'right': True}, ['green block', 'in', 'green bowl']
# multi_step: {'pick_obj': 'green block', 'relation': 'in', 'target_obj': 'green bowl', 'confidence': 0.712215, 'right': True}, ['green block', 'in', 'green bowl']
# top_k: {'pick_obj': 'green block', 'relation': 'in', 'target_obj': 'green bowl', 'confidence': 0.8, 'right': True}, ['green block', 'in', 'green bowl']
# conformal: {'pick_obj': 'green block', 'relation': 'in', 'target_obj': 'green bowl', 'confidence': np.float64(0.25263950117536144), 'right': True}, ['green block', 'in', 'green bowl']
# model0_rnd0: {'pick_obj': 'green block', 'relation': 'in', 'target_obj': 'green bowl', 'confidence': 0.9964324235916138, 'right': True}, ['green block', 'in', 'green bowl']
# model0_rnd30: {'pick_obj': 'green block', 'relation': 'in', 'target_obj': 'green bowl', 'confidence': 0.05247411131858826, 'right': True}, ['green block', 'in', 'green bowl']
# action: put the yellow block in the yellow bowl
# confidence: 0.9955459237098694
# action: put the yellow block in the yellow bowl
# confidence: 0.020084619522094727
# vanilla: {'pick_obj': 'yellow block', 'relation': 'in', 'target_obj': 'yellow bowl', 'confidence': 1.0, 'right': True}, ['yellow block', 'in', 'yellow bowl']
# cot: {'pick_obj': 'yellow block', 'relation': 'in', 'target_obj': 'yellow bowl', 'confidence': 1.0, 'right': True}, ['yellow block', 'in', 'yellow bowl']
# self_probing: {'pick_obj': 'yellow block', 'relation': 'in', 'target_obj': 'yellow bowl', 'confidence': 0.95, 'right': True}, ['yellow block', 'in', 'yellow bowl']
# self_probing_log: {'pick_obj': 'yellow block', 'relation': 'in', 'target_obj': 'yellow bowl', 'confidence': 0.0, 'right': True}, ['yellow block', 'in', 'yellow bowl']
# multi_step: {'pick_obj': 'yellow block', 'relation': 'in', 'target_obj': 'yellow bowl', 'confidence': 0.855, 'right': True}, ['yellow block', 'in', 'yellow bowl']
# top_k: {'pick_obj': 'yellow block', 'relation': 'in', 'target_obj': 'yellow bowl', 'confidence': 0.8, 'right': True}, ['yellow block', 'in', 'yellow bowl']
# conformal: {'pick_obj': 'yellow block', 'relation': 'in', 'target_obj': 'yellow bowl', 'confidence': np.float64(0.22020108365432334), 'right': True}, ['yellow block', 'in', 'yellow bowl']
# model0_rnd0: {'pick_obj': 'yellow block', 'relation': 'in', 'target_obj': 'yellow bowl', 'confidence': 0.9955459237098694, 'right': True}, ['yellow block', 'in', 'yellow bowl']
# model0_rnd30: {'pick_obj': 'yellow block', 'relation': 'in', 'target_obj': 'yellow bowl', 'confidence': 0.020084619522094727, 'right': True}, ['yellow block', 'in', 'yellow bowl']
# action: put the green block to the back of the green bowl
# confidence: 0.9945957660675049
# action: put the green block to the back of the green bowl
# confidence: 0.1390351839363575
# vanilla: {'pick_obj': 'green block', 'relation': 'in', 'target_obj': 'green bowl', 'confidence': 1.0, 'right': False}, ['green block', 'back', 'green bowl']
# cot: {'pick_obj': 'green block', 'relation': 'behind', 'target_obj': 'green bowl', 'confidence': 0.8, 'right': False}, ['green block', 'back', 'green bowl']
# self_probing: {'pick_obj': 'green bowl', 'relation': 'back', 'target_obj': 'green block', 'confidence': 0.6, 'right': False}, ['green block', 'back', 'green bowl']
# self_probing_log: {'pick_obj': 'green bowl', 'relation': 'back', 'target_obj': 'green block', 'confidence': 0.0, 'right': False}, ['green block', 'back', 'green bowl']
# multi_step: {'pick_obj': 'green block', 'relation': 'back', 'target_obj': 'green bowl', 'confidence': 0.43091999999999997, 'right': True}, ['green block', 'back', 'green bowl']
# top_k: {'pick_obj': 'green block', 'relation': 'in', 'target_obj': 'green bowl', 'confidence': 0.9, 'right': False}, ['green block', 'back', 'green bowl']
# conformal: {'pick_obj': 'green block', 'relation': 'back', 'target_obj': 'green bowl', 'confidence': np.float64(0.2452840106840438), 'right': True}, ['green block', 'back', 'green bowl']
# model0_rnd0: {'pick_obj': 'green block', 'relation': 'back', 'target_obj': 'green bowl', 'confidence': 0.9945957660675049, 'right': True}, ['green block', 'back', 'green bowl']
# model0_rnd30: {'pick_obj': 'green block', 'relation': 'back', 'target_obj': 'green bowl', 'confidence': 0.1390351839363575, 'right': True}, ['green block', 'back', 'green bowl']
# action: put the green block to the front of the green bowl
# confidence: 0.9987175464630127
# action: put the green block to the front of the green bowl
# confidence: 0.2750810794532299
# vanilla: {'pick_obj': 'green block', 'relation': 'in front of', 'target_obj': 'green bowl', 'confidence': 0.9, 'right': False}, ['green block', 'front', 'green bowl']
# cot: {'pick_obj': 'green block', 'relation': 'in front of', 'target_obj': 'green bowl', 'confidence': 0.8, 'right': False}, ['green block', 'front', 'green bowl']
# self_probing: {'pick_obj': 'green block', 'relation': 'front', 'target_obj': 'green bowl', 'confidence': 0.7, 'right': True}, ['green block', 'front', 'green bowl']
# self_probing_log: {'pick_obj': 'green block', 'relation': 'front', 'target_obj': 'green bowl', 'confidence': 0.0, 'right': True}, ['green block', 'front', 'green bowl']
# multi_step: {'pick_obj': 'green block', 'relation': 'front', 'target_obj': 'green bowl', 'confidence': 0.40698, 'right': True}, ['green block', 'front', 'green bowl']
# top_k: {'pick_obj': 'green block,', 'relation': 'front,', 'target_obj': 'green bowl', 'confidence': 0.8, 'right': False}, ['green block', 'front', 'green bowl']
# conformal: {'pick_obj': 'green block', 'relation': 'front', 'target_obj': 'green bowl', 'confidence': np.float64(0.243374195882163), 'right': True}, ['green block', 'front', 'green bowl']
# model0_rnd0: {'pick_obj': 'green block', 'relation': 'front', 'target_obj': 'green bowl', 'confidence': 0.9987175464630127, 'right': True}, ['green block', 'front', 'green bowl']
# model0_rnd30: {'pick_obj': 'green block', 'relation': 'front', 'target_obj': 'green bowl', 'confidence': 0.2750810794532299, 'right': True}, ['green block', 'front', 'green bowl']
# action: put the green block to the back of the green bowl
# confidence: 0.9945957660675049
# action: put the green block to the back of the green bowl
# confidence: 0.1390351839363575
# vanilla: {'pick_obj': 'green block', 'relation': 'back', 'target_obj': 'green bowl', 'confidence': 1.0, 'right': True}, ['green block', 'back', 'green bowl']
# cot: {'pick_obj': 'green block', 'relation': 'behind', 'target_obj': 'green bowl', 'confidence': 1.0, 'right': False}, ['green block', 'back', 'green bowl']
# self_probing: {'pick_obj': 'green bowl', 'relation': 'back', 'target_obj': 'green block', 'confidence': 0.8, 'right': False}, ['green block', 'back', 'green bowl']
# self_probing_log: {'pick_obj': 'green bowl', 'relation': 'back', 'target_obj': 'green block', 'confidence': 0.0, 'right': False}, ['green block', 'back', 'green bowl']
# multi_step: {'pick_obj': 'green block', 'relation': 'behind', 'target_obj': 'green bowl', 'confidence': 0.534888, 'right': False}, ['green block', 'back', 'green bowl']
# top_k: {'pick_obj': 'green block', 'relation': 'in', 'target_obj': 'green bowl', 'confidence': 0.8, 'right': False}, ['green block', 'back', 'green bowl']
# conformal: {'pick_obj': 'green block', 'relation': 'back', 'target_obj': 'green bowl', 'confidence': np.float64(0.24428837131094994), 'right': True}, ['green block', 'back', 'green bowl']
# model0_rnd0: {'pick_obj': 'green block', 'relation': 'back', 'target_obj': 'green bowl', 'confidence': 0.9945957660675049, 'right': True}, ['green block', 'back', 'green bowl']
# model0_rnd30: {'pick_obj': 'green block', 'relation': 'back', 'target_obj': 'green bowl', 'confidence': 0.1390351839363575, 'right': True}, ['green block', 'back', 'green bowl']
# action: put the yellow block in the bowl
# confidence: 0.31083354353904724
# action: put the yellow block in the bowl
# confidence: -0.4381413608789444
# vanilla: {'pick_obj': 'yellow block', 'relation': 'in', 'target_obj': 'yellow bowl', 'confidence': 1.0, 'right': True}, ['yellow block', 'in', 'yellow bowl']
# cot: {'pick_obj': 'yellow block', 'relation': 'in', 'target_obj': 'yellow bowl', 'confidence': 0.8, 'right': True}, ['yellow block', 'in', 'yellow bowl']
# self_probing: {'pick_obj': 'yellow block', 'relation': 'in', 'target_obj': 'yellow bowl"', 'confidence': 0.7, 'right': False}, ['yellow block', 'in', 'yellow bowl']
# self_probing_log: {'pick_obj': 'yellow block', 'relation': 'in', 'target_obj': 'yellow bowl"', 'confidence': 0.0, 'right': False}, ['yellow block', 'in', 'yellow bowl']
# multi_step: {'pick_obj': 'yellow block', 'relation': 'in', 'target_obj': 'yellow bowl', 'confidence': 0.67032, 'right': True}, ['yellow block', 'in', 'yellow bowl']
# top_k: {'pick_obj': 'yellow block', 'relation': 'in', 'target_obj': 'yellow bowl', 'confidence': 0.8, 'right': True}, ['yellow block', 'in', 'yellow bowl']
# conformal: {'pick_obj': 'yellow block', 'relation': 'in', 'target_obj': 'yellow bowl', 'confidence': np.float64(0.23359313737280507), 'right': True}, ['yellow block', 'in', 'yellow bowl']
# model0_rnd0: {'pick_obj': 'yellow block', 'relation': 'in', 'target_obj': 'yellow bowl', 'confidence': 0.31083354353904724, 'right': True}, ['yellow block', 'in', 'yellow bowl']
# model0_rnd30: {'pick_obj': 'yellow block', 'relation': 'in', 'target_obj': 'yellow bowl', 'confidence': -0.4381413608789444, 'right': True}, ['yellow block', 'in', 'yellow bowl']
# action: put the blue block in the bowl
# confidence: 0.026758069172501564
# action: put the blue block in the bowl
# confidence: -0.665919391438365
# vanilla: {'pick_obj': 'blue block', 'relation': 'in', 'target_obj': 'blue bowl', 'confidence': 1.0, 'right': False}, ['blue block', 'in', 'green bowl']
# cot: {'pick_obj': 'blue block', 'relation': 'in', 'target_obj': 'blue bowl', 'confidence': 0.8, 'right': False}, ['blue block', 'in', 'green bowl']
# self_probing: {'pick_obj': 'blue block', 'relation': 'in', 'target_obj': 'blue bowl', 'confidence': 0.7, 'right': False}, ['blue block', 'in', 'green bowl']
# self_probing_log: {'pick_obj': 'blue block', 'relation': 'in', 'target_obj': 'blue bowl', 'confidence': 0.0, 'right': False}, ['blue block', 'in', 'green bowl']
# multi_step: {'pick_obj': 'blue block', 'relation': 'in', 'target_obj': 'yellow bowl', 'confidence': 0.504, 'right': False}, ['blue block', 'in', 'green bowl']
# top_k: {'pick_obj': 'blue block', 'relation': 'in', 'target_obj': 'blue bowl', 'confidence': 0.7, 'right': False}, ['blue block', 'in', 'green bowl']
# conformal: {'pick_obj': 'blue block', 'relation': 'in', 'target_obj': 'blue bowl', 'confidence': np.float64(0.21602018658144473), 'right': False}, ['blue block', 'in', 'green bowl']
# model0_rnd0: {'pick_obj': 'blue block', 'relation': 'in', 'target_obj': 'blue bowl', 'confidence': 0.026758069172501564, 'right': False}, ['blue block', 'in', 'green bowl']
# model0_rnd30: {'pick_obj': 'blue block', 'relation': 'in', 'target_obj': 'blue bowl', 'confidence': -0.665919391438365, 'right': False}, ['blue block', 'in', 'green bowl']
# action: put the yellow block to the front of the yellow bowl
# confidence: 0.9988738298416138
# action: put the yellow block to the front of the yellow bowl
# confidence: 0.18572182208299637
# vanilla: {'pick_obj': 'yellow block', 'relation': 'in', 'target_obj': 'yellow bowl', 'confidence': 1.0, 'right': False}, ['yellow block', 'front', 'yellow bowl']
# cot: {'pick_obj': 'yellow block', 'relation': 'front', 'target_obj': 'yellow bowl', 'confidence': 1.0, 'right': True}, ['yellow block', 'front', 'yellow bowl']
# self_probing: {'pick_obj': 'yellow block', 'relation': 'in front of', 'target_obj': 'yellow bowl', 'confidence': 0.5, 'right': False}, ['yellow block', 'front', 'yellow bowl']
# self_probing_log: {'pick_obj': 'yellow block', 'relation': 'in front of', 'target_obj': 'yellow bowl', 'confidence': 0.0, 'right': False}, ['yellow block', 'front', 'yellow bowl']
# multi_step: {'pick_obj': 'yellow block', 'relation': 'front', 'target_obj': 'yellow bowl', 'confidence': 0.67032, 'right': True}, ['yellow block', 'front', 'yellow bowl']
# top_k: {'pick_obj': 'yellow block', 'relation': 'front', 'target_obj': 'yellow bowl', 'confidence': 0.8, 'right': True}, ['yellow block', 'front', 'yellow bowl']
# conformal: {'pick_obj': 'yellow block', 'relation': 'front', 'target_obj': 'yellow bowl', 'confidence': np.float64(0.2315924169315746), 'right': True}, ['yellow block', 'front', 'yellow bowl']
# model0_rnd0: {'pick_obj': 'yellow block', 'relation': 'front', 'target_obj': 'yellow bowl', 'confidence': 0.9988738298416138, 'right': True}, ['yellow block', 'front', 'yellow bowl']
# model0_rnd30: {'pick_obj': 'yellow block', 'relation': 'front', 'target_obj': 'yellow bowl', 'confidence': 0.18572182208299637, 'right': True}, ['yellow block', 'front', 'yellow bowl']
# action: put the yellow block close to the yellow bowl
# confidence: 0.00573387648910284
# action: put the yellow block close to the yellow bowl
# confidence: -0.7445191005244851
# vanilla: {'pick_obj': 'yellow block', 'relation': 'right', 'target_obj': 'yellow bowl', 'confidence': 0.8, 'right': True}, ['yellow block', 'right', 'yellow bowl']
# cot: {'pick_obj': 'yellow block', 'relation': 'front', 'target_obj': 'yellow bowl', 'confidence': 1.0, 'right': False}, ['yellow block', 'right', 'yellow bowl']
# self_probing: {'pick_obj': 'yellow block', 'relation': 'in front of', 'target_obj': 'yellow bowl', 'confidence': 0.8, 'right': False}, ['yellow block', 'right', 'yellow bowl']
# self_probing_log: {'pick_obj': 'yellow block', 'relation': 'in front of', 'target_obj': 'yellow bowl', 'confidence': 0.0, 'right': False}, ['yellow block', 'right', 'yellow bowl']
# multi_step: {'pick_obj': 'yellow block', 'relation': 'towards (assuming this is the most general direction)', 'target_obj': 'yellow bowl', 'confidence': 0.40698, 'right': False}, ['yellow block', 'right', 'yellow bowl']
# top_k: {'pick_obj': 'yellow block', 'relation': 'right', 'target_obj': 'yellow bowl', 'confidence': 0.8, 'right': True}, ['yellow block', 'right', 'yellow bowl']
# ...
# top_k: {'pick_obj': 'yellow block', 'relation': 'in', 'target_obj': 'yellow bowl', 'confidence': 0.8, 'right': True}, ['yellow block', 'in', 'yellow bowl']
# conformal: {'pick_obj': 'yellow block', 'relation': 'in', 'target_obj': 'yellow bowl', 'confidence': np.float64(0.24995952563364307), 'right': True}, ['yellow block', 'in', 'yellow bowl']
# model0_rnd0: {'pick_obj': 'yellow block', 'relation': 'in', 'target_obj': 'yellow bowl', 'confidence': 0.9955459237098694, 'right': True}, ['yellow block', 'in', 'yellow bowl']
# model0_rnd30: {'pick_obj': 'yellow block', 'relation': 'in', 'target_obj': 'yellow bowl', 'confidence': 0.020084619522094727, 'right': True}, ['yellow block', 'in', 'yellow bowl']
# action: put the green block close to the green bowl
# confidence: 0.017565077170729637
# action: put the green block close to the green bowl
# confidence: -0.6238914672285318
# vanilla: {'pick_obj': 'green block', 'relation': 'in', 'target_obj': 'green bowl', 'confidence': 0.8, 'right': False}, ['green block', 'back', 'green bowl']
# cot: {'pick_obj': 'green block', 'relation': 'in front of', 'target_obj': 'green bowl', 'confidence': 0.8, 'right': False}, ['green block', 'back', 'green bowl']
# self_probing: {'pick_obj': 'green block', 'relation': 'in', 'target_obj': 'green bowl', 'confidence': 0.75, 'right': False}, ['green block', 'back', 'green bowl']
# self_probing_log: {'pick_obj': 'green block', 'relation': 'in', 'target_obj': 'green bowl', 'confidence': 0.0, 'right': False}, ['green block', 'back', 'green bowl']
# multi_step: {'pick_obj': 'green block', 'relation': 'none', 'target_obj': 'green bowl', 'confidence': 0.096, 'right': False}, ['green block', 'back', 'green bowl']
# top_k: {'pick_obj': 'green block', 'relation': 'right', 'target_obj': 'green bowl', 'confidence': 0.8, 'right': False}, ['green block', 'back', 'green bowl']
# conformal: {'pick_obj': 'green block', 'relation': 'right', 'target_obj': 'green bowl', 'confidence': np.float64(0.21930913967905966), 'right': False}, ['green block', 'back', 'green bowl']
# model0_rnd0: {'pick_obj': 'green block', 'relation': 'right', 'target_obj': 'green bowl', 'confidence': 0.017565077170729637, 'right': False}, ['green block', 'back', 'green bowl']
# model0_rnd30: {'pick_obj': 'green block', 'relation': 'right', 'target_obj': 'green bowl', 'confidence': -0.6238914672285318, 'right': False}, ['green block', 'back', 'green bowl']
# action: put the green block in the green bowl
# confidence: 0.9964324235916138
# action: put the green block in the green bowl
# confidence: 0.05247411131858826
# vanilla: {'pick_obj': 'green block', 'relation': 'in', 'target_obj': 'green bowl', 'confidence': 1.0, 'right': True}, ['green block', 'in', 'green bowl']
# cot: {'pick_obj': 'green block', 'relation': 'in', 'target_obj': 'green bowl', 'confidence': 0.9, 'right': True}, ['green block', 'in', 'green bowl']
# self_probing: {'pick_obj': 'green block', 'relation': 'in', 'target_obj': 'green bowl', 'confidence': 0.8, 'right': True}, ['green block', 'in', 'green bowl']
# self_probing_log: {'pick_obj': 'green block', 'relation': 'in', 'target_obj': 'green bowl', 'confidence': 0.0, 'right': True}, ['green block', 'in', 'green bowl']
# multi_step: {'pick_obj': 'green block', 'relation': 'in', 'target_obj': 'green bowl', 'confidence': 0.58482, 'right': True}, ['green block', 'in', 'green bowl']
# top_k: {'pick_obj': 'green block', 'relation': 'in', 'target_obj': 'green bowl', 'confidence': 0.9, 'right': True}, ['green block', 'in', 'green bowl']
# conformal: {'pick_obj': 'green block', 'relation': 'in', 'target_obj': 'green bowl', 'confidence': np.float64(0.2657214802443661), 'right': True}, ['green block', 'in', 'green bowl']
# model0_rnd0: {'pick_obj': 'green block', 'relation': 'in', 'target_obj': 'green bowl', 'confidence': 0.9964324235916138, 'right': True}, ['green block', 'in', 'green bowl']
# model0_rnd30: {'pick_obj': 'green block', 'relation': 'in', 'target_obj': 'green bowl', 'confidence': 0.05247411131858826, 'right': True}, ['green block', 'in', 'green bowl']
# action: put the block in the yellow bowl
# confidence: 0.16406723856925964
# action: put the block in the yellow bowl
# confidence: -0.41989313811063766
# vanilla: {'pick_obj': 'yellow block', 'relation': 'in', 'target_obj': 'yellow bowl', 'confidence': 0.95, 'right': False}, ['blue block', 'in', 'yellow bowl']
# cot: {'pick_obj': 'green block', 'relation': 'in', 'target_obj': 'yellow bowl', 'confidence': 0.6, 'right': False}, ['blue block', 'in', 'yellow bowl']
# self_probing: {'pick_obj': 'yellow bowl', 'relation': 'in', 'target_obj': 'yellow block', 'confidence': 0.8, 'right': False}, ['blue block', 'in', 'yellow bowl']
# self_probing_log: {'pick_obj': 'yellow bowl', 'relation': 'in', 'target_obj': 'yellow block', 'confidence': 0.0, 'right': False}, ['blue block', 'in', 'yellow bowl']
# multi_step: {'pick_obj': 'green block', 'relation': 'in', 'target_obj': 'yellow bowl', 'confidence': 0.5814, 'right': False}, ['blue block', 'in', 'yellow bowl']
# top_k: {'pick_obj': 'yellow block', 'relation': 'in', 'target_obj': 'yellow bowl', 'confidence': 0.8, 'right': False}, ['blue block', 'in', 'yellow bowl']
# conformal: {'pick_obj': 'blue block', 'relation': 'in', 'target_obj': 'yellow bowl', 'confidence': np.float64(0.21521650367068154), 'right': True}, ['blue block', 'in', 'yellow bowl']
# model0_rnd0: {'pick_obj': 'blue block', 'relation': 'in', 'target_obj': 'yellow bowl', 'confidence': 0.16406723856925964, 'right': True}, ['blue block', 'in', 'yellow bowl']
# model0_rnd30: {'pick_obj': 'blue block', 'relation': 'in', 'target_obj': 'yellow bowl', 'confidence': -0.41989313811063766, 'right': True}, ['blue block', 'in', 'yellow bowl']
# action: put the block in the blue bowl
# confidence: 0.24490982294082642
# action: put the block in the blue bowl
# confidence: -0.6716469302773476
# vanilla: {'pick_obj': 'blue block', 'relation': 'in', 'target_obj': 'blue bowl', 'confidence': 0.8, 'right': True}, ['blue block', 'in', 'blue bowl']
# cot: {'pick_obj': 'blue block', 'relation': 'in', 'target_obj': 'blue bowl', 'confidence': 0.6, 'right': True}, ['blue block', 'in', 'blue bowl']
# self_probing: {'pick_obj': 'blue block', 'relation': 'in', 'target_obj': 'blue bowl', 'confidence': 0.7, 'right': True}, ['blue block', 'in', 'blue bowl']
# self_probing_log: {'pick_obj': 'blue block', 'relation': 'in', 'target_obj': 'blue bowl', 'confidence': 0.0, 'right': True}, ['blue block', 'in', 'blue bowl']
# multi_step: {'pick_obj': 'blue block', 'relation': 'in', 'target_obj': 'blue bowl', 'confidence': 0.67032, 'right': True}, ['blue block', 'in', 'blue bowl']
# top_k: {'pick_obj': 'blue block', 'relation': 'in', 'target_obj': 'blue bowl', 'confidence': 0.8, 'right': True}, ['blue block', 'in', 'blue bowl']
# conformal: {'pick_obj': 'blue block', 'relation': 'in', 'target_obj': 'blue bowl', 'confidence': np.float64(0.23723060817343672), 'right': True}, ['blue block', 'in', 'blue bowl']
# model0_rnd0: {'pick_obj': 'blue block', 'relation': 'in', 'target_obj': 'blue bowl', 'confidence': 0.24490982294082642, 'right': True}, ['blue block', 'in', 'blue bowl']
# model0_rnd30: {'pick_obj': 'blue block', 'relation': 'in', 'target_obj': 'blue bowl', 'confidence': -0.6716469302773476, 'right': True}, ['blue block', 'in', 'blue bowl']
# action: put the blue block in the bowl
# confidence: 0.026758069172501564
# action: put the blue block in the bowl
# confidence: -0.665919391438365
# vanilla: {'pick_obj': 'blue block', 'relation': 'in', 'target_obj': 'blue bowl', 'confidence': 1.0, 'right': False}, ['blue block', 'in', 'green bowl']
# cot: {'pick_obj': 'blue block', 'relation': 'in', 'target_obj': 'blue bowl', 'confidence': 0.8, 'right': False}, ['blue block', 'in', 'green bowl']
# self_probing: {'pick_obj': 'blue block', 'relation': 'in', 'target_obj': 'blue bowl', 'confidence': 0.8, 'right': False}, ['blue block', 'in', 'green bowl']
# self_probing_log: {'pick_obj': 'blue block', 'relation': 'in', 'target_obj': 'blue bowl', 'confidence': 0.0, 'right': False}, ['blue block', 'in', 'green bowl']
# multi_step: {'pick_obj': 'blue block', 'relation': 'in', 'target_obj': 'blue bowl', 'confidence': 0.636804, 'right': False}, ['blue block', 'in', 'green bowl']
# top_k: {'pick_obj': 'blue block', 'relation': 'in', 'target_obj': 'blue bowl', 'confidence': 0.85, 'right': False}, ['blue block', 'in', 'green bowl']
# conformal: {'pick_obj': 'blue block', 'relation': 'in', 'target_obj': 'blue bowl', 'confidence': np.float64(0.2355559986767426), 'right': False}, ['blue block', 'in', 'green bowl']
# model0_rnd0: {'pick_obj': 'blue block', 'relation': 'in', 'target_obj': 'blue bowl', 'confidence': 0.026758069172501564, 'right': False}, ['blue block', 'in', 'green bowl']
# model0_rnd30: {'pick_obj': 'blue block', 'relation': 'in', 'target_obj': 'blue bowl', 'confidence': -0.665919391438365, 'right': False}, ['blue block', 'in', 'green bowl']
# action: put the block in the green bowl
# confidence: 0.029461117461323738
# action: put the block in the green bowl
# confidence: -0.7857862543314695
# vanilla: {'pick_obj': 'green block', 'relation': 'in', 'target_obj': 'green bowl', 'confidence': 1.0, 'right': True}, ['green block', 'in', 'green bowl']
# cot: {'pick_obj': 'green block', 'relation': 'in', 'target_obj': 'green bowl', 'confidence': 0.6, 'right': True}, ['green block', 'in', 'green bowl']
# self_probing: {'pick_obj': 'green block', 'relation': 'in', 'target_obj': 'green bowl', 'confidence': 0.8, 'right': True}, ['green block', 'in', 'green bowl']
# self_probing_log: {'pick_obj': 'green block', 'relation': 'in', 'target_obj': 'green bowl', 'confidence': 0.0, 'right': True}, ['green block', 'in', 'green bowl']
# multi_step: {'pick_obj': 'green block', 'relation': 'in', 'target_obj': 'green bowl', 'confidence': 0.684, 'right': True}, ['green block', 'in', 'green bowl']
# top_k: {'pick_obj': 'green block', 'relation': 'in', 'target_obj': 'green bowl', 'confidence': 0.6, 'right': True}, ['green block', 'in', 'green bowl']
# conformal: {'pick_obj': 'yellow block', 'relation': 'in', 'target_obj': 'green bowl', 'confidence': np.float64(0.22682480680330674), 'right': False}, ['green block', 'in', 'green bowl']
# model0_rnd0: {'pick_obj': 'yellow block', 'relation': 'in', 'target_obj': 'green bowl', 'confidence': 0.029461117461323738, 'right': False}, ['green block', 'in', 'green bowl']
# model0_rnd30: {'pick_obj': 'yellow block', 'relation': 'in', 'target_obj': 'green bowl', 'confidence': -0.7857862543314695, 'right': False}, ['green block', 'in', 'green bowl']
# action: put the block in the yellow bowl
# confidence: 0.1727302223443985
# action: put the block in the yellow bowl
# confidence: -0.6866233386099339
# vanilla: {'pick_obj': 'yellow block', 'relation': 'in', 'target_obj': 'yellow bowl', 'confidence': 0.9, 'right': False}, ['blue block', 'in', 'yellow bowl']
# cot: {'pick_obj': 'yellow block', 'relation': 'in', 'target_obj': 'yellow bowl', 'confidence': 0.6, 'right': False}, ['blue block', 'in', 'yellow bowl']
# self_probing: {'pick_obj': 'yellow bowl', 'relation': 'in', 'target_obj': 'yellow block', 'confidence': 0.5, 'right': False}, ['blue block', 'in', 'yellow bowl']
# self_probing_log: {'pick_obj': 'yellow bowl', 'relation': 'in', 'target_obj': 'yellow block', 'confidence': 0.0, 'right': False}, ['blue block', 'in', 'yellow bowl']
# multi_step: {'pick_obj': 'yellow block', 'relation': 'in', 'target_obj': 'yellow bowl', 'confidence': 0.7200000000000001, 'right': False}, ['blue block', 'in', 'yellow bowl']
# top_k: {'pick_obj': 'yellow block', 'relation': 'in', 'target_obj': 'yellow bowl', 'confidence': 0.6, 'right': False}, ['blue block', 'in', 'yellow bowl']
# conformal: {'pick_obj': 'yellow block', 'relation': 'in', 'target_obj': 'yellow bowl', 'confidence': np.float64(0.22675879718660166), 'right': False}, ['blue block', 'in', 'yellow bowl']
# model0_rnd0: {'pick_obj': 'yellow block', 'relation': 'in', 'target_obj': 'yellow bowl', 'confidence': 0.1727302223443985, 'right': False}, ['blue block', 'in', 'yellow bowl']
# model0_rnd30: {'pick_obj': 'yellow block', 'relation': 'in', 'target_obj': 'yellow bowl', 'confidence': -0.6866233386099339, 'right': False}, ['blue block', 'in', 'yellow bowl']
# action: put the block in the blue bowl
# confidence: 0.24490982294082642
# action: put the block in the blue bowl
# confidence: -0.6716469302773476
# vanilla: {'pick_obj': 'blue block', 'relation': 'in', 'target_obj': 'blue bowl', 'confidence': 1.0, 'right': False}, ['yellow block', 'in', 'blue bowl']
# cot: {'pick_obj': 'blue block', 'relation': 'in', 'target_obj': 'blue bowl', 'confidence': 0.8, 'right': False}, ['yellow block', 'in', 'blue bowl']
# self_probing: {'pick_obj': 'blue bowl', 'relation': 'in', 'target_obj': 'blue block', 'confidence': 0.8, 'right': False}, ['yellow block', 'in', 'blue bowl']
# self_probing_log: {'pick_obj': 'blue bowl', 'relation': 'in', 'target_obj': 'blue block', 'confidence': 0.0, 'right': False}, ['yellow block', 'in', 'blue bowl']
# multi_step: {'pick_obj': 'blue block', 'relation': 'in', 'target_obj': 'blue bowl', 'confidence': 0.67032, 'right': False}, ['yellow block', 'in', 'blue bowl']
# top_k: {'pick_obj': 'blue block', 'relation': 'in', 'target_obj': 'blue bowl', 'confidence': 0.7, 'right': False}, ['yellow block', 'in', 'blue bowl']
# conformal: {'pick_obj': 'blue block', 'relation': 'in', 'target_obj': 'blue bowl', 'confidence': np.float64(0.25136506538830417), 'right': False}, ['yellow block', 'in', 'blue bowl']
# model0_rnd0: {'pick_obj': 'blue block', 'relation': 'in', 'target_obj': 'blue bowl', 'confidence': 0.24490982294082642, 'right': False}, ['yellow block', 'in', 'blue bowl']
# model0_rnd30: {'pick_obj': 'blue block', 'relation': 'in', 'target_obj': 'blue bowl', 'confidence': -0.6716469302773476, 'right': False}, ['yellow block', 'in', 'blue bowl']
# self_probing
# self_probing_log
# vanilla
# cot
# conformal
# model0_rnd30
# top_k
# model0_rnd0
# multi_step
# [{'experiment_name': 'self_probing', 'confidence_with_right': np.float64(0.7446564885496183), 'confidence_without_right': np.float64(0.7006410256410255), 'sr_hr_area': np.float64(0.26205813270698747)}, {'experiment_name': 'self_probing_log', 'confidence_with_right': np.float64(0.0), 'confidence_without_right': np.float64(0.0), 'sr_hr_area': np.float64(0.02247015071442533)}, {'experiment_name': 'vanilla', 'confidence_with_right': np.float64(0.9616438356164384), 'confidence_without_right': np.float64(0.9184397163120568), 'sr_hr_area': np.float64(0.3168906052657144)}, {'experiment_name': 'cot', 'confidence_with_right': np.float64(0.8695121951219511), 'confidence_without_right': np.float64(0.7387195121951219), 'sr_hr_area': np.float64(0.45443089430894335)}, {'experiment_name': 'conformal', 'confidence_with_right': np.float64(0.23401747487412175), 'confidence_without_right': np.float64(0.22191714739660748), 'sr_hr_area': np.float64(0.41829618768328436)}, {'experiment_name': 'model0_rnd30', 'confidence_with_right': np.float64(-0.20535613473339548), 'confidence_without_right': np.float64(-0.7056039730223622), 'sr_hr_area': np.float64(0.6539560117302052)}, {'experiment_name': 'top_k', 'confidence_with_right': np.float64(0.7794520547945205), 'confidence_without_right': np.float64(0.7585106382978722), 'sr_hr_area': np.float64(0.07012581365976853)}, {'experiment_name': 'model0_rnd0', 'confidence_with_right': np.float64(0.6802830140008741), 'confidence_without_right': np.float64(0.11330354792307569), 'sr_hr_area': np.float64(0.653394916911046)}, {'experiment_name': 'multi_step', 'confidence_with_right': np.float64(0.5318869810471918), 'confidence_without_right': np.float64(0.500648578030688), 'sr_hr_area': np.float64(0.08713446031283373)}]
# /tmp/ipykernel_145071/3480780993.py:86: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   sr_hr_area[experiment_name] = np.trapz(success_rate_conditioned_on_confidence[experiment_name], dx=1) / divider

# %%
res
for r in res:
    print(r['experiment_name'], r['sr_hr_area'])
# Out:
# self_probing 0.26205813270698747
# self_probing_log 0.02247015071442533
# vanilla 0.3168906052657144
# cot 0.45443089430894335
# conformal 0.41829618768328436
# model0_rnd30 0.6539560117302052
# top_k 0.07012581365976853
# model0_rnd0 0.653394916911046
# multi_step 0.08713446031283373

# %%
success = 0
for data in all_data:
    if data['result']['conformal']['right']:
        success += 1
print(success/len(all_data))
# Out:
# 0.5400696864111498
